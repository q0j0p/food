# %% [markdown]
# ## 'I Made It' page in allrecipes.com's member page
#
# Just get:
# - recipe ID, name
# - rating for recipe (optional, as it's redundant)
#
# Click on 'more' button if possible.

# %%
import pymongo 
from bs4 import BeautifulSoup as BS
import re
import collections

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
allrecipes_db = client.allrecipes

# %%
allrecipes_db.collection_names()
# Out:
# [u'members',
#  u'webpages',
#  u'community_link_pages',
#  u'communiy_page',
#  u'community_page']

# %%
members_coll = allrecipes_db.members

# %%
members_coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'allrecipes'), u'members')

# %%
# Get all the key names 
# 

members_coll.find_one().keys()
# Out:
# [u'favorites_page',
#  u'following_page',
#  u'reviews_page',
#  u'followers_page',
#  u'madeit_page',
#  u'link',
#  u'member_ID',
#  u'_id',
#  u'recipes_page']

# %%
# 
soup = BS(members_coll.find_one()['madeit_page'], 'html.parser')

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}
#   </style>
#   <title>
#    Public Profile - Allrecipes.com
#   </title>
#   <meta content="Follow me on Allrecipes!" property="og:title"/>
#   <meta content="Allrecipes" property="og:site_name"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="See the recipes I’m saving, making, and sharing with friends. Let’s cook together." property="og:description"/>
#   <meta content="noindex, follow" name="robots"/>
#   <link href="http://allrecipes.com/cook/64043/made-it/" id="canonicalUrl" rel="canonical"/>
#   <meta content="http://allrecipes.com/cook/64043/" property="og:url"/>
#   <link href="http://css01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/main-css.bundled.Css" rel="stylesheet"/>
#   <link href="http://css01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/recipe-print-css.bundled.Css" rel="stylesheet"/>
#   <meta content="profile" property="og:type"/>
#   <meta content="http://images.media-allrecipes.com/mobile/allrecipes/images/icon-user-default_v2.png" property="og:image"/>
#   <meta content="250" property="og:image:width"/>
#   <meta content="250" property="og:image:height"/>
#   <meta content="66102450266" property="fb:app_id"/>
#   <script src="https://bam.nr-data.net/1/55db0cb698?a=33298262&amp;v=1026.7a27a3e&amp;to=YwABYUUDXUIABRZbCVpKIllbEFZSCBYHQTFRBxBcQwccYRMJBFsKUSYMW0MQXF0NAxAcNkEHD1xUSho%3D&amp;rst=11673&amp;ref=http://allrecipes.com/cook/64043/made-it/&amp;ap=2441&amp;be=3075&amp;fe=11352&amp;dc=4159&amp;af=err,xhr,stn,ins,spa&amp;perf=%7B%22timing%22:%7B%22of%22:1490139639699,%22n%22:0,%22u%22:2790,%22ue%22:2816,%22f%22:102,%22dn%22:102,%22dne%22:102,%22c%22:102,%22ce%22:102,%22rq%22:147,%22rp%22:2789,%22rpe%22:2910,%22dl%22:2790,%22di%22:4092,%22ds%22:4159,%22de%22:4988,%22dc%22:11349,%22l%22:11351,%22le%22:11561%7D,%22navigation%22:%7B%7D%7D&amp;jsonp=NREUM.setToken" type="text/javascript">
#   </script>
#   <script src="https://securepubads.g.doubleclick.net/gampad/ads?gdfp_req=1&amp;correlator=2965748233113245&amp;output=json_html&amp;callback=googletag.impl.pubads.callbackProxy1&amp;impl=fifs&amp;json_a=1&amp;eid=108809080&amp;sc=0&amp;sfv=1-0-6&amp;iu_parts=3865%2Car.mdp.mob%2Ctier1%2Cprofile&amp;enc_prev_ius=0%2F1%2F2%2F3&amp;prev_iu_szs=320x50&amp;prev_scp=slot%3Dmob-adhesive-banner-fixed%26IOM%3D9_5%26IPM%3D%26ybot_ad%3Dn%26rpfl_12738%3D43_tier0010%26rpfl_elemid%3Ddiv-gpt-mob-adhesive-banner-fixed&amp;eri=1&amp;cust_params=pv%3D15%26type%3Dprofile%26status%3Dvisitor%26oid%3D2C68AA38851D1930-6000190260008C0F%26fit%3D0%26id%3D0%26breakpoint%3Dmobile%26contentType%3Dpublicprofile%26geo%3DUSA%26ksg%3Dpol9z7q4l%26kuid%3Drnpsnoi92%26refreshType%3Dhard&amp;cookie=ID%3Ddd5e4b78d884e206%3AT%3D1490113652%3AS%3DALNI_MZ7eQfkoxoPuQktXxqY6b1A08U78g&amp;lmt=1490139651&amp;dt=1490139651339&amp;cc=100&amp;frm=20&amp;biw=752&amp;bih=672&amp;oid=3&amp;adxs=216&amp;adys=622&amp;adks=1943714211&amp;gut=v2&amp;ifi=1&amp;u_tz=-420&amp;u_his=30&amp;u_java=true&amp;u_h=800&amp;u_w=1280&amp;u_ah=777&amp;u_aw=1276&amp;u_cd=24&amp;u_nplug=13&amp;u_nmime=46&amp;u_sd=2&amp;flash=24.0.0&amp;url=http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F&amp;dssz=52&amp;icsg=1433763162750976&amp;mso=2177&amp;std=18&amp;vrg=111&amp;vrp=111&amp;ga_vid=637015273.1490113651&amp;ga_sid=1490139651&amp;ga_hid=324112102">
#   </script>
#   <script src="http://cdn.krxd.net/userdata/get?pub=1b008fc9-b074-4b2e-8e4a-c1e1f07d344b&amp;kxfp=20097e2ea48228e9f2abd2fd6cbde48127b8d744&amp;kfuid=LIwAHukb&amp;callback=Krux.ns._default.kxjsonp_userdata" type="text/javascript">
#   </script>
#   <script src="http://beacon.krxd.net/optout_check?callback=Krux.ns._default.kxjsonp_optOutCheck" type="text/javascript">
#   </script>
#   <script src="https://js-agent.newrelic.com/nr-spa-1026.min.js">
#   </script>
#   <script async="" src="http://aax.amazon-adsystem.com/e/dtb/bid?src=3446&amp;u=http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F&amp;pid=6713522651490139650807&amp;cb=8097676891490139650811&amp;ws=767x672&amp;v=4.0.0&amp;t=1000&amp;slots=[%7B%22id%22:%22div-gpt-mob-adhesive-banner-fixed%22,%22s%22:[%22320x50%22]%7D]" type="text/javascript">
#   </script>
#   <script src="http://ads-adswest-vpc.yldbt.com/m/e529/v1/init?cb=yieldbot.updateState&amp;v=v2015-06-23%7Ce14513e&amp;vi=j0jr701p68fgd8netb&amp;si=j0k6ck9ms1iigmllt9&amp;pvi=j0k6o99qjiew3xq48o&amp;pvd=15&amp;lpvi=j0k6npsiuevid26lcm&amp;sn=div-gpt-mob-adhesive-banner-fixed-tier1&amp;ssz=320x50&amp;lo=http%3A//allrecipes.com/cook/64043/made-it/&amp;r=&amp;sd=1280x800&amp;to=7&amp;la=en-US&amp;np=MacIntel&amp;ua=Mozilla/5.0%20%28Macintosh%3B%20Intel%20Mac%20OS%20X%2010.12%3B%20rv%3A45.0%29%20Gecko/20100101%20Firefox/45.0&amp;lpv=25244&amp;cts_ns=1490139639699&amp;cts_js=1490139650788&amp;cts_ini=1490139650800&amp;e">
#   </script>
#   <script async="" src="http://gads.pubmatic.com/AdServer/AdCallAggregator?SAVersion=1000&amp;js=1&amp;kltstamp=2017-3-21%2016%3A40%3A49&amp;timezone=-7&amp;screenResolution=1280x800&amp;ranreq=0.17990487029550672&amp;pageURL=http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F&amp;inIframe=0&amp;kadpageurl=http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F&amp;pubId=37576&amp;pm_cb=pm_async_callback&amp;a=1&amp;adslots=%5Bar.mdp.mob.tier1%40320x50%5D">
#   </script>
#   <script async="" src="https://c.amazon-adsystem.com/aax2/apstag.js">
#   </script>
#   <script src="//ads.rubiconproject.com/header/12738.js">
#   </script>
#   <script async="" src="http://ads.pubmatic.com/AdServer/js/gshowad.js">
#   </script>
#   <script src="http://cdn.yldbt.com/js/yieldbot.intent.js">
#   </script>
#   <script src="http://as.casalemedia.com/cygnus?v=7&amp;fn=cygnus_index_parse_res&amp;s=178489&amp;r=%7B%22id%22%3A367958470%2C%22site%22%3A%7B%22page%22%3A%22http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F%22%2C%22ref%22%3A%22%22%7D%2C%22imp%22%3A%5B%7B%22id%22%3A%221%22%2C%20%22banner%22%3A%7B%22w%22%3A320%2C%22h%22%3A50%2C%22topframe%22%3A1%7D%2C%22ext%22%3A%20%7B%22sid%22%3A%229%22%2C%22siteID%22%3A178535%7D%7D%5D%7D&amp;t=1000" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script async="" src="//cdn.krxd.net/ctjs/controltag.js.6f097431db32c7c9f9254dccb9812402">
#   </script>
#   <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-MW2LG9&amp;l=placeholderDL">
#   </script>
#   <script async="" id="foresee-js" src="//images.media-allrecipes.com/ar/foresee/v0.7/foresee-trigger.js" type="text/javascript">
#   </script>
#   <script async="" src="//google-analytics.com/analytics.js">
#   </script>
#   <script async="" src="//connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="http://cdn.krxd.net/controltag?confid=H1gAR3V7" type="text/javascript">
#   </script>
#   <script async="" src="http://b.scorecardresearch.com/beacon.js">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"55db0cb698","applicationID":"33298262","transactionName":"YwABYUUDXUIABRZbCVpKIllbEFZSCBYHQTFRBxBcQwccYRMJBFsKUSYMW0MQXF0NAxAcNkEHD1xUSho=","queueTime":0,"applicationTime":2441,"agent":"","atts":""}
#   </script>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"XQ4OVVdaGwADVlhaBQcF"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o&lt;n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&amp;&amp;console.log(t)}catch(e){}}var o,i=t("ee"),a=t(19),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&amp;&amp;"function"==typeof console.log&amp;&amp;(c.console=!0,o.indexOf("dev")!==-1&amp;&amp;(c.dev=!0),o.indexOf("nr_dev")!==-1&amp;&amp;(c.nrDev=!0))}catch(s){}c.nrDev&amp;&amp;i.on("internal-error",function(t){r(t.stack)}),c.dev&amp;&amp;i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&amp;&amp;(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,e,n)])}catch(c){try{i("ierr",[c,s.now(),!0])}catch(u){}}return"function"==typeof f&amp;&amp;f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t){i("err",[t,s.now()])}var i=t("handle"),a=t(20),c=t("ee"),s=t("loader"),f=window.onerror,u=!1,d=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(p){"stack"in p&amp;&amp;(t(12),t(11),"addEventListener"in window&amp;&amp;t(6),s.xhrWrappable&amp;&amp;t(13),u=!0)}c.on("fn-start",function(t,e,n){u&amp;&amp;(d+=1)}),c.on("fn-err",function(t,e,n){u&amp;&amp;(this.thrown=!0,o(n))}),c.on("fn-end",function(){u&amp;&amp;!this.thrown&amp;&amp;d&gt;0&amp;&amp;(d-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){C++,N=y.hash,this[u]=M.now()}function o(){C--,y.hash!==N&amp;&amp;i(0,!0);var t=M.now();this[l]=~~this[l]+t-this[u],this[d]=t}function i(t,e){x.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=M.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,h="cb"+s,l="jsTime",m="fetch",v="addEventListener",w=window,y=w.location;if(w[v]){var b=t(9),g=t(10),x=t(8),E=t(6),O=t(12),R=t(7),P=t(13),T=t("ee"),S=T.get("tracer");t(14);var M=t("loader");M.features.spa=!0;var N,j=w[v],C=0;T.on(u,r),T.on(p,r),T.on(d,o),T.on(h,o),T.buffer([u,d,"xhr-done","xhr-resolved"]),E.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),P.buffer([u,"new-xhr","send-xhr"+c]),R.buffer([m+c,m+"-done",m+f+c,m+f+s]),x.buffer(["newURL"]),b.buffer([u]),g.buffer(["propagate",p,h,"executor-err","resolve"+c]),S.buffer([u,"no-"+u]),a(P,"send-xhr"+c),a(T,"xhr-resolved"),a(T,"xhr-done"),a(R,m+c),a(R,m+"-done"),x.on("pushState-end",i),x.on("replaceState-end",i),j("hashchange",i,!0),j("load",i,!0),j("popstate",function(){i(0,C&gt;1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&amp;&amp;window.performance.timing&amp;&amp;window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(12),c=t(11),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",h="-start",l="-end",m="fn"+h,v="fn"+l,w="bstTimer",y="pushState",b=t("loader");b.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&amp;&amp;(this.bstStart=b.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&amp;&amp;i("bst",[n,e,this.bstStart,b.now()])}),a.on(m,function(t,e,n){this.bstStart=b.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,b.now(),this.bstType])}),c.on(m,function(){this.bstStart=b.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,b.now(),"requestAnimationFrame"])}),o.on(y+h,function(t){this.time=b.now(),this.startPath=location.pathname+location.hash}),o.on(y+l,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.perform ...
#   </script>
#   <!-- Begin comScore Tag - Part 1 -->
#   <script>
#    var _comscore = _comscore || [];
#         _comscore.push({ c1: "2", c2: "6036305" });
#         (function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#             s.async = true;
#             s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#         })();
#   </script>
#   <!-- End comScore Tag Part 1-->
#   <link href="/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#   <link href="/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <!-- Maxymiser script start -->
#   <script src="//service.maxymiser.net/cdn/allrecipes/js/mmcore.js" type="text/javascript">
#   </script>
#   <style id="mm_style_mm_cdApiStyleId_1" media="screen" type="text/css">
#   </style>
#   <script id="mmpack.0" src="//service.maxymiser.net/platform/us/api/mmpackage-1.8.js" type="text/javascript">
#   </script>
#   <!-- Maxymiser script end -->
#   <script src="//assets.adobedtm.com/1c2ad567a53f27e563c4dc2c278a904b84dc5fde/satelliteLib-a07d47e4668bf3c3fa98aff5b2fc6d3f1d0981a3.js">
#   </script>
#   <script src="http://js01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/main-top.bundled.js">
#   </script>
#   <meta content="bab2de7a-335c-49a5-b980-c2cf0457197c" name="correlationId"/>
#   <script src="http://assets.adobedtm.com/1c2ad567a53f27e563c4dc2c278a904b84dc5fde/scripts/satellite-565cbeb564746d560c001f46.js">
#   </script>
#   <meta content="" name="description"/>
#   <style>
#    [data-columns]::before{display:block;visibility:hidden;position:absolute;font-size:1px;}
#   </style>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_111.js">
#   </script>
#   <link href="//fastlane.rubiconproject.com/" rel="dns-prefetch"/>
#   <link href="http://tpc.googlesyndication.com/safeframe/1-0-6/html/container.html" rel="prefetch"/>
#   <script src="http://images.media-allrecipes.com/ar/foresee/v0.7/foresee-surveydef.js?build=9" type="text/javascript">
#   </script>
#   <script async="" id="pubApiioRpChND" src="//api.sele.co/ub/v1.jsonp?ka_type=profile&amp;ka_status=visitor&amp;ka_oid=2C68AA38851D1930-6000190260008C0F&amp;ka_fit=0&amp;ka_id=0&amp;ka_breakpoint=mobile&amp;ka_contentType=publicprofile&amp;ka_geo=USA&amp;ka_pv=15&amp;ka_ksg=%5B%22pol9z7q4l%22%5D&amp;ka_kuid=rnpsnoi92&amp;debugLevel=5&amp;sm_os=Macintosh&amp;sm_plt=mouse&amp;sm_brw=Firefox&amp;sm_pr=2&amp;sm_w=752&amp;sm_h=672&amp;sm_o=l&amp;sm_fp=4047013571&amp;sm_pb=ioRpChND&amp;utid=1490139651509&amp;loc=http%3A%2F%2Fallrecipes.com%2Fcook%2F64043%2Fmade-it%2F&amp;ref=&amp;sm_cb=smpubApiioRpChND36203384" type="text/javascript">
#   </script>
#  </head>
#  <!-- ARLOG SERVER: RD0003FFA8D30A LOCAL_IP: 10.255.18.12 MERCH_KEY: MerchData_77_1_1_0_***_51_68 -->
#  <body class="ng-scope" ng-app="allrecipes">
#   <a id="top">
#   </a>
#   <a class="newThisMonth" href="/new-this-month/" rel="nofollow" target="_self">
#    New this month
#   </a>
#   <!-- Begin comScore Tag - Part 2 -->
#   <noscript>
#    &lt;img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6036305&amp;cv=2.0&amp;cj=1" /&gt;
#   </noscript>
#   <!-- End comScore Tag - Part 2 -->
#   <div class="slider-container" global-ui-events="">
#    <div class="ad-non-mobile-only" id="div-opa__pushdown-wrapper" style="display:none;">
#     <div class="opa__pushdown" id="ad-pushdown-placeholder">
#     </div>
#    </div>
#    <div class="site-content">
#     <one-time-message-banner>
#      <div class="tos-banner ng-hide" data-ng-hide="hideMessage">
#       <span class="close" data-ng-click="hideBanner()">
#       </span>
#       <a class="tos-banner__content" href="http://www.meredith.com/legal/terms" target="_blank">
#        <span>
#         WE'VE UPDATED OUR TERMS OF SERVICE
#        </span>
#        . By continuing to use this site, you agree to the site's updated
#        <span>
#         Terms of Service
#        </span>
#        .
#       </a>
#      </div>
#     </one-time-message-banner>
#     <header class="header new-nav">
#      <section class="ng-scope" ng-controller="ar_controllers_top_nav" ng-init="init()">
#       <ul class="ar-nav-section">
#        <li class="ar-logo-tab">
#         <a href="/" target="_self">
#          <div class="ar-logo" ng-click="setAnalyticsCookie('ARlogo')">
#           <img alt="Allrecipes" height="36" src="http://images.media-allrecipes.com/ar-images/ARlogo.svg" width="96"/>
#          </div>
#         </a>
#        </li>
#        <li class="browse-recipes">
#         <a class="recipes-txt {active:topBrowseRecipePanel_showing}" href="" id="navmenu_recipes" popup-trigger="topBrowseRecipePanel">
#          <span>
#           BROWSE
#          </span>
#          <span class="icon--chevron-down">
#          </span>
#         </a>
#        </li>
#        <li class="search-tab ng-scope" ng-controller="ar_controllers_search">
#         <div class="nav-search">
#          <input class="ng-pristine ng-untouched ng-valid" id="searchText" ng-keypress="isEnterKey($event) &amp;&amp; performSearch()" ng-model="search.keywords" placeholder="Find a recipe" type="text"/>
#          <button class="btn-basic--small search-button" ng-click="performSearch()">
#           <span class="icon svg-icon--top-nav-bar--search-magnify svg-icon--top-nav-bar--search-magnify-dims">
#           </span>
#          </button>
#          <div ar-event-focus="click" ar-event-focus-id="setFocus-keywordSearch" class="ingredient-searchtxt" id="ingredientSearch" popup-trigger="topNavSearchMenu">
#           Ingredient Search
#          </div>
#         </div>
#        </li>
#        <li class="social-notification" id="541340e3-5eda-45b1-a739-1da22db05c5f" ng-class="{active: notifications_showing}" popup-trigger="notifications">
#         <div class="socialNotification ng-scope" ng-click="setNotificationsViewed()" ng-controller="ar_controllers_notifications">
#          <span class="svg-icon--top-nav-bar--nav-bell svg-icon--top-nav-bar--nav-bell-dims">
#          </span>
#          <span class="notification-count ng-binding" ng-bind="notificationCount" ng-show="displayCount">
#           1
#          </span>
#         </div>
#        </li>
#        <li class="nav-favorites" ng-click="setAnalyticsCookie('favorites')">
#         <a href="/cook/my/favorites/" target="_self">
#          <span class="svg-icon--top-nav-bar--grey-heart svg-icon--top-nav-bar--grey-heart-dims">
#          </span>
#         </a>
#        </li>
#        <li class="nav-profile anonymous-user">
#         <a href="/account/authenticationwelcome/" target="_self">
#          <div class="login-state">
#           <div class="img-profile icon svg-icon--top-nav-bar--userhead svg-icon--top-nav-bar--userhead-dims" ng-click="setAnalyticsCookie('profile|profile')">
#           </div>
#           <span class="username icon-user--default" id="offCanvasDisplayName" ng-click="setAnalyticsCookie('create profile|sign up')">
#            Create a profile
#           </span>
#          </div>
#         </a>
#        </li>
#        <li class="small-screen search-phone--landscape" ng-class="{active:topNavSearchMenu_showing}">
#         <a ar-event-focus="click" ar-event-focus-id="setFocus-keywordSearch" href="" id="d6acf778-a245-4838-8511-48fb69a89ef8" popup-trigger="topNavSearchMenu">
#          <div class="nav-search">
#           <span>
#            <img alt="search" height="23" src="http://images.media-allrecipes.com/ar-images/icons/NavSearchIcon.svg" width="23"/>
#           </span>
#          </div>
#         </a>
#        </li>
#        <li class="small-screen profile-phone--landscape" id="3a942351-2056-46b5-acaf-9351356f6e47" ng-class="{active:topNavProfileMenu_showing}" popup-trigger="topNavProfileMenu">
#         <a href="">
#          <div class="login-state">
#           <div class="img-profile icon svg-icon--top-nav-bar--userhead svg-icon--top-nav-bar--userhead-dims">
#           </div>
#          </div>
#         </a>
#        </li>
#        <li class="hamburger-tab" id="ebf39d29-1987-4339-bf6a-2885d211b105" ng-class="{active: topNavHamburgerMenu_showing}" popup-trigger="topNavHamburgerMenu">
#         <a href="">
#          <div class="hamburger-nav">
#           <span class="browse-recipes-iconbar">
#           </span>
#           <span class="browse-recipes-iconbar">
#           </span>
#           <span class="browse-recipes-iconbar">
#           </span>
#          </div>
#         </a>
#        </li>
#       </ul>
#       <social-notification id="7c2cf75c-053f-4a59-b992-254a7918dc31" popup-panel="notifications">
#        <div class="nav-tab notification-menu unauthenticated-message ng-hide ng-scope" id="f3cff84a-e246-4cd4-a49e-874bfce71219" ng-controller="ar_controllers_notifications" popup-panel="notifications">
#         <ul class="nav-tab__options">
#          <li class="unauthenticated">
#           <h2>
#            Cook in good company
#           </h2>
#           <ul>
#            <li>
#             Connect with like-minded cooks
#            </li>
#            <li>
#             Celebrate your cooking triumphs
#            </li>
#            <li>
#             Discover new favorite recipes
#            </li>
#           </ul>
#           <a class="btn-gold" href="/account/authenticationwelcome/" ng-click="setAnalyticsCookie('notification|sign up')" target="_self">
#            Sign up (free)
#           </a>
#          </li>
#         </ul>
#        </div>
#       </social-notification>
#       <div class="nav-tab nav-tab__search ng-hide" id="4d5eb84f-8ef4-4e12-9eda-ee2eff732cfe" popup-panel="topNavSearchMenu">
#        <form class="ng-pristine ng-valid">
#         <div class="ng-scope" data-ng-controller="ar_controllers_search">
#          <span class="icon--close" hidewhenclicked="" title="Close Ingredient Search">
#          </span>
#          <div class="input-wrap--home">
#           <span class="search-spyglass">
#            <img alt="Allrecipes" height="23" src="http://images.media-allrecipes.com/ar-images/icons/NavSearchIcon.svg" width="23"/>
#           </span>
#           <input class="setFocus-keywordSearch ng-pristine ng-untouched ng-valid" id="searchText" ng-model="search.keywords" placeholder="Keywords" type="text"/>
#          </div>
#          <div ar-assign-scrollable-classes="{ outermostWrapper: 'ingredients', clippingFrame: 'ingredient-clipping-frame', draggableElement: 'ingredient-scroller' }" class="input-wrap--home ingredients">
#           <div class="ingredient-clipping-frame">
#            <ul ar-touchend="touchEnd($event)" ar-touchstart="touchStart($event)" class="ingredient-scroller ng-scope" ng-mousedown="mouseDown($event)" ng-mouseup="mouseUp($event)" onselectstart="return false;" unselectable="on">
#             <!-- ngRepeat: ingredient in search.ingredientsInclude -->
#            </ul>
#           </div>
#           <div class="ingredient-add-exclude">
#            <input class="setFocus-includeIng ng-pristine ng-untouched ng-valid" id="includeIngText" name="txtIncludeIng" ng-attr-placeholder="{{includeIngPlaceholderText}}" ng-blur="showAds()" ng-focus="hideAds();" ng-keydown="(isBackspaceKey($event) &amp;&amp; removeLastIngredientInclude($event)) || (isTabKey($event) &amp;&amp; addIngredientInclude($event))" ng-model="includeIngredient" placeholder="Include ingredients" type="text"/>
#           </div>
#           <a ar-event-focus="click" ar-event-focus-id="setFocus-includeIng" class="btn-basic--small include" ng-class="{ 'grayed-out': includeIngHitMax }" ng-click="addIngredientInclude($event)">
#            <span>
#             +
#            </span>
#           </a>
#          </div>
#          <div ar-assign-scrollable-classes="{ outermostWrapper: 'ingredients', clippingFrame: 'ingredient-clipping-frame', draggableElement: 'ingredient-scroller' }" class="input-wrap--home ingredients">
#           <div class="ingredient-clipping-frame">
#            <ul ar-touchend="touchEnd($event)" ar-touchstart="touchStart($event)" class="ingredient-scroller ng-scope" ng-mousedown="mouseDown($event)" ng-mouseup="mouseUp($event)" onselectstart="return false;" unselectable="on">
#             <!-- ngRepeat: ingredient in search.ingredientsExclude -->
#            </ul>
#           </div>
#           <div class="ingredient-add-exclude">
#            <input class="setFocus-excludeIng ng-pristine ng-untouched ng-valid" id="excludeIngText" name="txtExcludeIng" ng-attr-placeholder="{{excludeIngPlaceholderText}}" ng-blur="showAds()" ng-focus="hideAds();" ng-keydown="(isBackspaceKey($event) &amp;&amp; removeLastIngredientExclude($event)) || (isTabKey($event) &amp;&amp; addIngredientExclude($event))" ng-model="excludeIngredient" placeholder="Exclude ingredients" type="text"/>
#           </div>
#           <a ar-event-focus="click" ar-event-focus-id="setFocus-excludeIng" class="btn-basic--small exclude" ng-class="{ 'grayed-out': excludeIngHitMax }" ng-click="addIngredientExclude($event)">
#            <span>
#             —
#            </span>
#           </a>
#          </div>
#          <div class="nav-tab__buttons">
#           <button class="btn-basic--small btn-search" ng-click="performSearch()">
#            Go
#           </button>
#          </div>
#         </div>
#         <div class="notification hidden" id="msg-toolbar">
#          <span class="notification__message">
#          </span>
#         </div>
#        </form>
#       </div>
#       <div class="browse-recipe-tab social ng-hide" id="topBrowseRecipePanel" popup-panel="topBrowseRecipePanel">
#        <section class="hero-link nav-tab__options recipe-nav-tab__options">
#         <div class="grid underline_hero_link">
#          <ul class="browse-hubs">
#           <li class="browse-hubs__categories">
#            <h3>
#             Meal Type
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/76/appetizers-and-snacks/" ng-click="setAnalyticsCookie('browse|appetizers \u0026 snacks')" target="_self" title="Appetizers &amp; Snacks Recipes">
#               Appetizers &amp; Snacks
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/78/breakfast-and-brunch/" ng-click="setAnalyticsCookie('browse|breakfast \u0026 brunch')" target="_self" title="Breakfast &amp; Brunch Recipes">
#               Breakfast &amp; Brunch
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/79/desserts/" ng-click="setAnalyticsCookie('browse|desserts')" target="_self" title="Desserts Recipes">
#               Desserts
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/17562/dinner/" ng-click="setAnalyticsCookie('browse|dinner')" target="_self" title="Dinner Recipes">
#               Dinner
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/77/drinks/" ng-click="setAnalyticsCookie('browse|drinks')" target="_self" title="Drinks Recipes">
#               Drinks
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Ingredient
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/200/meat-and-poultry/beef/" ng-click="setAnalyticsCookie('browse|beef')" target="_self" title="Beef Recipes">
#               Beef
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/201/meat-and-poultry/chicken/" ng-click="setAnalyticsCookie('browse|chicken')" target="_self" title="Chicken Recipes">
#               Chicken
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/95/pasta-and-noodles/" ng-click="setAnalyticsCookie('browse|pasta')" target="_self" title="Pasta Recipes">
#               Pasta
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/205/meat-and-poultry/pork/" ng-click="setAnalyticsCookie('browse|pork')" target="_self" title="Pork Recipes">
#               Pork
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/416/seafood/fish/salmon/" ng-click="setAnalyticsCookie('browse|salmon')" target="_self" title="Salmon Recipes">
#               Salmon
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Diet &amp; Health
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/739/healthy-recipes/diabetic/" ng-click="setAnalyticsCookie('browse|diabetic')" target="_self" title="Diabetic Recipes">
#               Diabetic
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/741/healthy-recipes/gluten-free/" ng-click="setAnalyticsCookie('browse|gluten free')" target="_self" title="Gluten Free Recipes">
#               Gluten Free
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/84/healthy-recipes/" ng-click="setAnalyticsCookie('browse|healthy')" target="_self" title="Healthy Recipes">
#               Healthy
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1232/healthy-recipes/low-calorie/" ng-click="setAnalyticsCookie('browse|low calorie')" target="_self" title="Low Calorie Recipes">
#               Low Calorie
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1231/healthy-recipes/low-fat/" ng-click="setAnalyticsCookie('browse|low fat')" target="_self" title="Low Fat Recipes">
#               Low Fat
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Seasonal
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="http://allrecipes.com/recipes/194/holidays-and-events/passover/" ng-click="setAnalyticsCookie('browse|passover')" target="_self" title="Passover Recipes">
#               Passover
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/188/holidays-and-events/easter/" ng-click="setAnalyticsCookie('browse|easter')" target="_self" title="Easter Recipes">
#               Easter
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/1509/holidays-and-events/cinco-de-mayo/" ng-click="setAnalyticsCookie('browse|cinco de mayo')" target="_self" title="Cinco de Mayo Recipes">
#               Cinco de Mayo
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/1445/holidays-and-events/mothers-day/" ng-click="setAnalyticsCookie('browse|mother\u0027s day')" target="_self" title="Mother's Day Recipes">
#               Mother's Day
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/85/holidays-and-events/" ng-click="setAnalyticsCookie('browse|more holidays and events')" target="_self" title="More Holidays and Events Recipes">
#               More Holidays and Events
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Dish Type
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/156/bread/" ng-click="setAnalyticsCookie('browse|breads')" target="_self" title="Breads Recipes">
#               Breads
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/276/desserts/cakes/" ng-click="setAnalyticsCookie('browse|cakes')" target="_self" title="Cakes Recipes">
#               Cakes
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/96/salad/" ng-click="setAnalyticsCookie('browse|salads')" target="_self" title="Salads Recipes">
#               Salads
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/138/drinks/smoothies/" ng-click="setAnalyticsCookie('browse|smoothies')" target="_self" title="Smoothies Recipes">
#               Smoothies
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/94/soups-stews-and-chili/" ng-click="setAnalyticsCookie('browse|soups, stews \u0026 chili')" target="_self" title="Soups, Stews &amp; Chili Recipes">
#               Soups, Stews &amp; Chili
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Cooking Style
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/88/bbq-grilling/" ng-click="setAnalyticsCookie('browse|bbq \u0026 grilling')" target="_self" title="BBQ &amp; Grilling Recipes">
#               BBQ &amp; Grilling
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1947/everyday-cooking/quick-and-easy/" ng-click="setAnalyticsCookie('browse|quick \u0026 easy')" target="_self" title="Quick &amp; Easy Recipes">
#               Quick &amp; Easy
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/253/everyday-cooking/slow-cooker/" ng-click="setAnalyticsCookie('browse|slow cooker')" target="_self" title="Slow Cooker Recipes">
#               Slow Cooker
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1227/everyday-cooking/vegan/" ng-click="setAnalyticsCookie('browse|vegan')" target="_self" title="Vegan Recipes">
#               Vegan
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/87/everyday-cooking/vegetarian/" ng-click="setAnalyticsCookie('browse|vegetarian')" target="_self" title="Vegetarian Recipes">
#               Vegetarian
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             World Cuisine
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="/recipes/227/world-cuisine/asian/" ng-click="setAnalyticsCookie('browse|asian')" target="_self" title="Asian Recipes">
#               Asian
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/233/world-cuisine/asian/indian/" ng-click="setAnalyticsCookie('browse|indian')" target="_self" title="Indian Recipes">
#               Indian
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/723/world-cuisine/european/italian/" ng-click="setAnalyticsCookie('browse|italian')" target="_self" title="Italian Recipes">
#               Italian
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/728/world-cuisine/latin-american/mexican/" ng-click="setAnalyticsCookie('browse|mexican')" target="_self" title="Mexican Recipes">
#               Mexican
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/15876/us-recipes/southern/" ng-click="setAnalyticsCookie('browse|southern')" target="_self" title="Southern Recipes">
#               Southern
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="browse-hubs__categories">
#            <h3>
#             Special Collections
#            </h3>
#            <span class="icon--chevron-right">
#            </span>
#            <ul class="browse-hubs__subcategories">
#             <li>
#              <a href="http://allrecipes.com/recipes/17235/everyday-cooking/allrecipes-magazine-recipes/" ng-click="setAnalyticsCookie('browse|allrecipes magazine recipes')" target="_self" title="Allrecipes Magazine Recipes">
#               Allrecipes Magazine Recipes
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/16791/everyday-cooking/special-collections/web-show-recipes/food-wishes/" ng-click="setAnalyticsCookie('browse|food wishes with chef john')" target="_self" title="Food Wishes with Chef John Recipes">
#               Food Wishes with Chef John
#              </a>
#             </li>
#             <li>
#              <a href="http://dish.allrecipes.com/trusted-brand-pages/" ng-click="setAnalyticsCookie('browse|trusted brands')" target="_self" title="Trusted Brands Recipes">
#               Trusted Brands
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#         <a class="recipe-hero-link__item__text" href="/recipes?grouping=all" ng-click="setAnalyticsCookie('browse|all categories')" target="_self">
#          All Categories
#         </a>
#        </section>
#       </div>
#       <!-- user sign in area -->
#       <div class="nav-tab social profile-nav ng-hide" id="42fe7c83-27bd-43f4-979e-a27051ca9f97" popup-panel="topNavProfileMenu">
#        <ul class="nav-tab__options">
#         <li ng-click="setAnalyticsCookie('profile|feed', 'menu')">
#          <a href="/account/authenticationwelcome/?loginReferrerUrl=/home" id="navmenu_myFeed" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--home svg-icon--top-nav-bar--home-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Feed
#           </span>
#          </a>
#         </li>
#         <li ng-click="setAnalyticsCookie('profile|profile', 'menu')">
#          <a href="/cook/my/" id="navmenu_myprofile" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--nav-profile svg-icon--top-nav-bar--nav-profile-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Profile
#           </span>
#          </a>
#         </li>
#         <li ng-click="setAnalyticsCookie('profile|favorites', 'menu')">
#          <a href="/cook/my/favorites/" id="navmenu_recipebox" rel="nofollow" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--grey-heart svg-icon--top-nav-bar--grey-heart-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Favorites
#           </span>
#          </a>
#         </li>
#         <li ng-click="setAnalyticsCookie('profile|friends', 'menu')">
#          <a href="/cook/my/findfriends/" id="navmenu_findfriends" rel="nofollow" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--nav-friends svg-icon--top-nav-bar--nav-friends-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Friends
#           </span>
#          </a>
#         </li>
#         <li ng-click="setAnalyticsCookie('profile|shopping list', 'menu')">
#          <a href="/my/shopping-lists/" id="navmenu_shoppinglist" rel="nofollow" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--grey-shopping svg-icon--top-nav-bar--grey-shopping-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Shopping List
#           </span>
#          </a>
#         </li>
#         <li ng-click="setAnalyticsCookie('profile|settings', 'menu')">
#          <a href="/cook/my/account-settings/" id="navmenu_settings" rel="nofollow" target="_self">
#           <span class="iconContainer">
#            <span class="icon svg-icon--top-nav-bar--nav-settings svg-icon--top-nav-bar--nav-settings-dims">
#            </span>
#           </span>
#           <span class="itemText">
#            Settings
#           </span>
#          </a>
#         </li>
#        </ul>
#        <div class="signin" ng-click="setAnalyticsCookie('profile|sign in ', 'menu')">
#         <button class="btn-basic--large btn-gold" id="navmenu_signin_signup" onclick=" location.href='/account/authenticationwelcome/?actionsource=' +(typeof dataLayer !=='undefined' ? dataLayer.page.category.contentType : '' ) ">
#          Sign In
#          <em>
#           or
#          </em>
#          Sign Up
#         </button>
#        </div>
#       </div>
#       <!-- hub links, etc. -->
#       <div class="nav-tab last ng-hide" id="353a9c59-0295-49a3-a238-0c76125db236" popup-panel="topNavHamburgerMenu">
#        <ul class="nav-tab__options">
#         <li class="underline_link">
#          <a href="" id="navmenu_recipes" ng-click="browseNav()" popup-trigger="browseRecipePanel">
#           <span class="icon svg-icon--top-nav-bar--nav-browse-orange svg-icon--top-nav-bar--nav-browse-orange-dims" ng-class="{'active': isActive}">
#           </span>
#           <span class="icon svg-icon--top-nav-bar--nav-browse svg-icon--top-nav-bar--nav-browse-dims" ng-class="{'hidden': isActive}">
#           </span>
#           <span class="nav-link-text">
#            Browse Recipes
#           </span>
#           <span class="icon-chevron" ng-class="{'active': isActive}">
#           </span>
#          </a>
#         </li>
#         <li class="browse-div-option ng-hide" id="mobile-nav-container" popup-panel="browseRecipePanel">
#          <ul class="nav-tab__mobile-browse">
#           <li>
#            <input id="Meal Type" type="checkbox"/>
#            <label for="Meal Type">
#             Meal Type
#             <span class="icon-chevron">
#             </span>
#            </label>
#            <ul class="mobile-browse-subnav">
#             <li>
#              <a href="/recipes/76/appetizers-and-snacks/" ng-click="setAnalyticsCookie('browse|appetizers \u0026 snacks')" target="_self" title="Appetizers &amp; Snacks Recipes">
#               Appetizers &amp; Snacks
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/78/breakfast-and-brunch/" ng-click="setAnalyticsCookie('browse|breakfast \u0026 brunch')" target="_self" title="Breakfast &amp; Brunch Recipes">
#               Breakfast &amp; Brunch
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/79/desserts/" ng-click="setAnalyticsCookie('browse|desserts')" target="_self" title="Desserts Recipes">
#               Desserts
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/17562/dinner/" ng-click="setAnalyticsCookie('browse|dinner')" target="_self" title="Dinner Recipes">
#               Dinner
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/77/drinks/" ng-click="setAnalyticsCookie('browse|drinks')" target="_self" title="Drinks Recipes">
#               Drinks
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <input id="Ingredient" type="checkbox"/>
#            <label for="Ingredient">
#             Ingredient
#             <span class="icon-chevron">
#             </span>
#            </label>
#            <ul class="mobile-browse-subnav">
#             <li>
#              <a href="/recipes/200/meat-and-poultry/beef/" ng-click="setAnalyticsCookie('browse|beef')" target="_self" title="Beef Recipes">
#               Beef
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/201/meat-and-poultry/chicken/" ng-click="setAnalyticsCookie('browse|chicken')" target="_self" title="Chicken Recipes">
#               Chicken
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/95/pasta-and-noodles/" ng-click="setAnalyticsCookie('browse|pasta')" target="_self" title="Pasta Recipes">
#               Pasta
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/205/meat-and-poultry/pork/" ng-click="setAnalyticsCookie('browse|pork')" target="_self" title="Pork Recipes">
#               Pork
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/416/seafood/fish/salmon/" ng-click="setAnalyticsCookie('browse|salmon')" target="_self" title="Salmon Recipes">
#               Salmon
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <input id="Diet &amp; Health" type="checkbox"/>
#            <label for="Diet &amp; Health">
#             Diet &amp; Health
#             <span class="icon-chevron">
#             </span>
#            </label>
#            <ul class="mobile-browse-subnav">
#             <li>
#              <a href="/recipes/739/healthy-recipes/diabetic/" ng-click="setAnalyticsCookie('browse|diabetic')" target="_self" title="Diabetic Recipes">
#               Diabetic
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/741/healthy-recipes/gluten-free/" ng-click="setAnalyticsCookie('browse|gluten free')" target="_self" title="Gluten Free Recipes">
#               Gluten Free
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/84/healthy-recipes/" ng-click="setAnalyticsCookie('browse|healthy')" target="_self" title="Healthy Recipes">
#               Healthy
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1232/healthy-recipes/low-calorie/" ng-click="setAnalyticsCookie('browse|low calorie')" target="_self" title="Low Calorie Recipes">
#               Low Calorie
#              </a>
#             </li>
#             <li>
#              <a href="/recipes/1231/healthy-recipes/low-fat/" ng-click="setAnalyticsCookie('browse|low fat')" target="_self" title="Low Fat Recipes">
#               Low Fat
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <input id="Seasonal" type="checkbox"/>
#            <label for="Seasonal">
#             Seasonal
#             <span class="icon-chevron">
#             </span>
#            </label>
#            <ul class="mobile-browse-subnav">
#             <li>
#              <a href="http://allrecipes.com/recipes/194/holidays-and-events/passover/" ng-click="setAnalyticsCookie('browse|passover')" target="_self" title="Passover Recipes">
#               Passover
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/188/holidays-and-events/easter/" ng-click="setAnalyticsCookie('browse|easter')" target="_self" title="Easter Recipes">
#               Easter
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/1509/holidays-and-events/cinco-de-mayo/" ng-click="setAnalyticsCookie('browse|cinco de mayo')" target="_self" title="Cinco de Mayo Recipes">
#               Cinco de Mayo
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/1445/holidays-and-events/mothers-day/" ng-click="setAnalyticsCookie('browse|mother\u0027s day')" target="_self" title="Mother's Day Recipes">
#               Mother's Day
#              </a>
#             </li>
#             <li>
#              <a href="http://allrecipes.com/recipes/85/holidays-and-events/" ng-click="setAnalyticsCookie('browse|more holidays and events')" target="_self" title="More Holidays and Events Recipes">
#               More Holidays and Events
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <input id="Dish Type" type="checkbox"/>
#            <label for="Dish Type">
#             Dish Type
#             <span class="icon-chevron">
#             </span>
#            </label>
#            <ul class="mobile-browse-subnav">
#             <li>
#              <a href="/recipes/156/bread/" ng-click="setAnalyticsCookie('browse|breads')" target="_self" title="Breads Recipes">
#               Breads
#              </a>
#             </li>
#             <li>
# ...
#         window.localStorage.setItem("CurrentUserStateModelExpirationDate", Date.now() + thirtyMinutesInMilliseconds); //primarily used by private profile SPA, but pertains to current user in general
#         window.localStorage.setItem("PublicProfileStateModelExpirationDate", Date.now() + thirtyMinutesInMilliseconds); //used by public profile SPA
#     } catch(err)  {
#         var CurrentUserStateCookie ='{"DisplayName":null,"AboutMe":null,"IsPro":false,"IsAllstar":false,"Id":0,"CookImageId":0,"Thumbnail":null,"FollowersCount":0,"FollowingCount":0,"FavoriteCount":0,"MadeRecipesCount":0,"RatingCount":0,"PersonalRecipeSharedCount":0,"SubmittedRecipesCount":0,"CoverImage":null,"City":null,"Region":null,"Country":null,"IsPrivate":false,"CityName":null,"RegionName":null,"CountryName":null,"LocationString":null,"IsFacebookConnected":false,"BrandedProfileSourceId":0,"PixelTrackingUrl":null,"PersonalWebsite":null,"FacebookUrl":null,"TwitterUrl":null,"PinterestUrl":null,"GPlusUrl":null,"AnalyticTrackingIdentifier":null,"ProfileImageShareUrl":null,"HasPersonalRecipes":false,"HasSharedPersonalRecipes":false,"Handle":null,"Tagline":null,"ThumbnailUrl":"http://images.media-allrecipes.com/mobile/allrecipes/images/icon-user-default_v2.png","ProfileUrl":"","AboutMeUrl":"","FavoritesUrl":"","CollectionsUrl":"","MadeItUrl":"","ReviewsUrl":"","RecipesUrl":"","FollowersUrl":"","FollowingUrl":""}';
#         var PublicProfileStateCookie = '{"DisplayName":"Snoopy498","AboutMe":"I detest recipes that call for things like boxed cake mix, can of cream of \u0026quot;fill in the blank\u0026quot; soup, onion dip mix, etc.. I do wish they would exile those kinds of \u0026quot;recipes\u0026quot; to a separate section so that I don\u0026#39;t ever have to waste my time reading a recipe that would not be of interest to me. \n\nI am constantly on the lookout for side dishes that are healthy, not sweet and not startchy. I pretty much fail.  I noticed a collard greens recipe but I\u0026#39;m sure collard greens are bitter. Don\u0026#39;t people know bitter is a bad things? (joking, I know it\u0026#39;s healthy). I mean bitter is used to describe things in a bad way. I am very bitter about this. \n\nI collect vintage cookie cutters. The only one I know of that I do not have is this rare fish cookie cutter. If anyone has one for sale, please do contact me.  Here is a YouTube video of that elusive cookie cutter.\nhttp://www.youtube.com/watch?v=5-oZmQO5oMg","IsPro":false,"IsAllstar":false,"Id":64043,"CookImageId":0,"Thumbnail":"https://secureimages.allrecipes.com/mobile/allrecipes/images/icon-user-default_v2.png","FollowersCount":1,"FollowingCount":0,"FavoriteCount":1346,"MadeRecipesCount":31,"RatingCount":25,"PersonalRecipeSharedCount":2,"SubmittedRecipesCount":0,"CoverImage":"http://images.media-allrecipes.com/ar-images/profiles/covers/books-coffee-header.jpg","City":"","Region":"","Country":"","IsPrivate":false,"CityName":"","RegionName":"","CountryName":"","LocationString":"","IsFacebookConnected":false,"BrandedProfileSourceId":0,"PixelTrackingUrl":null,"PersonalWebsite":"","FacebookUrl":"","TwitterUrl":"","PinterestUrl":"","GPlusUrl":"","AnalyticTrackingIdentifier":null,"ProfileImageShareUrl":"http://images.media-allrecipes.com/mobile/allrecipes/images/icon-user-default_v2.png","HasPersonalRecipes":true,"HasSharedPersonalRecipes":true,"Handle":"","Tagline":"","ThumbnailUrl":"https://secureimages.allrecipes.com/mobile/allrecipes/images/icon-user-default_v2.png","ProfileUrl":"/cook/64043/","AboutMeUrl":"/cook/64043/about-me/","FavoritesUrl":"/cook/64043/favorites/","CollectionsUrl":"/cook/64043/collections/","MadeItUrl":"/cook/64043/made-it/","ReviewsUrl":"/cook/64043/reviews/","RecipesUrl":"/cook/64043/recipes/","FollowersUrl":"/cook/64043/followers/","FollowingUrl":"/cook/64043/following/"}';
#         document.cookie = "CurrentUserStateModel=" + CurrentUserStateCookie;
#         document.cookie = "PublicProfileStateModel=" + PublicProfileStateCookie;
#     }
#   </script>
#   <script src="http://js01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/analytics.bundled.js">
#   </script>
#   <script src="http://js01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/main-bottom.bundled.js">
#   </script>
#   <script src="http://karma.mdpcdn.com/service/js-min/karma.footer.js">
#   </script>
#   <script src="http://css01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/main-bottom-templates.bundled.js">
#   </script>
#   <script>
#    angular.module('allrecipes').constant('Constant', { 'version': '1.63.0.3893-betterswap' });
#   </script>
#   <script>
#    AR.FacebookPixel.init();
#   </script>
#   <script src="http://js01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/old-masonry.bundled.js">
#   </script>
#   <script src="http://js01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/profile.bundled.js">
#   </script>
#   <script src="http://css01.media-allrecipes.com/assets/deployables/v-1.63.0.3893-betterswap/profile-templates.bundled.js">
#   </script>
#   <script>
#    $(document).ready(function () {
#         pubsub.broadcast("GoogleAnalytics");
#     });
#
#     if (typeof (window.dataLayer) !== "undefined" &amp;&amp; dataLayer) {
#         var clientAnalytics = new ClientAnalytics(window.dataLayer);
#         var comscoreShim = new ComscoreShim(window.dataLayer, pubsub);
#         var omniShim = new OmnitureShim(window.dataLayer, s, pubsub);
#         var kruxShim = new KruxShim(window.dataLayer, pubsub);
#         var gaShim = new GoogleAnalyticsShim(window.dataLayer, ga, pubsub);
#     }
#   </script>
#   <!-- Google Tag Manager -->
#   <noscript>
#    &lt;iframe src="//www.googletagmanager.com/ns.html?id=GTM-MW2LG9" height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','placeholderDL','GTM-MW2LG9');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script type="text/javascript">
#    _satellite.pageBottom(); // Initialize Adobe DTM
#   </script>
#   <link href="http://images.media-allrecipes.com/ar/foresee/v0.7/foresee-dhtml.css" rel="stylesheet"/>
#   <script type="extole/context">
#    {"params": {"e": "","tag:cook_id": "0"}}
#   </script>
#   <script id="" type="text/javascript">
#    console.log(google_tag_manager["GTM-MW2LG9"].macro('gtm1'));
#   </script>
#   <div class="kxhead" data-id="H1gAR3V7" style="display:none !important;">
#    <span class="kxtag kxinvisible" data-id="18851">
#     <script type="text/javascript">
#      Krux('social.init');
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18180">
#     <script>
#      (function() {
#   if (window.dataLayer &amp;&amp; window.dataLayer.page &amp;&amp; window.dataLayer.page.category &amp;&amp; window.dataLayer.page.category.adKeys) {
#     var ad_key = window.dataLayer.page.category.adKeys;
#     var ad_key_values;
#
#     if (ad_key !=null &amp;&amp; ad_key != "")  {
#
#     ad_key = ad_key.split(";");
#
#     for (i = 0; i &lt; ad_key.length; i++) {
#        if (ad_key[i].substring(0,2) == "k=") {
#
#     ad_key_values = ad_key[i].replace("[", "");
#     ad_key_values = ad_key_values.replace("]", "");
#     ad_key_values = ad_key_values.replace(/,/g, ";k=");
#
#     Krux('set', {'page_attr_adkeyvalues': ad_key_values });
#        }
#     }
#   }
# }})();
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18185">
#     <script>
#      if (window.dataLayer) {
#
#    var ga_pagename = "";
#    var ga_channel = "";
#    var ga_category = "";
#    var ga_subcategory = "";
#    var ga_memberlogin = "";
#    var ga_searchterm = "";
#    var ga_sponsorname = "";
#    var ga_newslettersource = "";
#    var ga_contenttype = "";
#    var ga_slideshows_quizzes = "";
#    var ga_application = "";
#
# for (var i = dataLayer.length - 1; i &gt; -1; i--) {
#
#    if ('Page Name' in dataLayer[i]) {
#       ga_pagename = dataLayer[i]["Page Name"];
#       Krux('set', {'page_attr_ga_pagename': ga_pagename });
#       }
#
#    if ('Channel' in dataLayer[i]) {
#       ga_channel = dataLayer[i]["Channel"];
#       Krux('set', {'page_attr_ga_channel': ga_channel });
#       }
#
#    if ('Category' in dataLayer[i]) {
#       ga_category = dataLayer[i]["Category"];
#       Krux('set', {'page_attr_ga_category': ga_category });
#       }
#
#     if ('Subcategory' in dataLayer[i]) {
#       ga_subcategory = dataLayer[i]["Subcategory"];
#       Krux('set', {'page_attr_ga_subcategory': ga_subcategory });
#       }
#
#     if ('Member Logged In' in dataLayer[i]) {
#       ga_memberlogin = dataLayer[i]["Member Logged In"];
#       Krux('set', {'page_attr_ga_memberlogin': ga_memberlogin });
#       }
#
#     if ('Search Term' in dataLayer[i]) {
#       ga_searchterm = dataLayer[i]["Search Term"];
#       Krux('set', {'page_attr_ga_searchterm': ga_searchterm });
#       }
#
#     if ('Sponsor Name' in dataLayer[i]) {
#       ga_sponsorname = dataLayer[i]["Sponsor Name"];
#       Krux('set', {'page_attr_ga_sponsorname': ga_sponsorname });
#       }
#
#     if ('Newsletter Signup Source' in dataLayer[i]) {
#       ga_newslettersource = dataLayer[i]["Newsletter Signup Source"];
#       Krux('set', {'page_attr_ga_newslettersource': ga_newslettersource });
#       }
#
#     if ('Content Type' in dataLayer[i]) {
#       ga_contenttype = dataLayer[i]["Content Type"];
#       Krux('set', {'page_attr_ga_contenttype': ga_contenttype });
#       }
#
#     if ('Slideshows and Quizzes' in dataLayer[i]) {
#       ga_slideshows_quizzes = dataLayer[i]["Slideshows and Quizzes"];
#       Krux('set', {'page_attr_ga_slideshows_quizzes': ga_slideshows_quizzes });
#       }
#
#     if ('Application' in dataLayer[i]) {
#       ga_application = dataLayer[i]["Application"];
#       Krux('set', {'page_attr_ga_application': ga_application });
#       }
#    }
# }
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18120">
#     <script>
#      (function(){
#     if(window.s){
#         if(window.s.eVar13){
#             Krux('set', 'page_attr_eVar13', window.s.eVar13);
#         }
#         if(window.s.eVar14){
#             Krux('set', 'page_attr_eVar14', window.s.eVar14);
#         }
#         if(window.s.eVar29){
#             Krux('set', 'page_attr_eVar29', window.s.eVar29);
#         }
#         if(window.s.channel){
#             Krux('set', 'page_attr_channel', window.s.channel);
#         }
#         if(window.s.prop1){
#             Krux('set', 'page_attr_prop1', window.s.prop1);
#         }
#     }
# })();
# Krux('set', 'page_attr_omniture_prop8', typeof window.s =='object' &amp;&amp; window.s['prop8']);
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18124">
#     <script>
#      // Using Omniture eVar32 to produce page attribute omniture_evar29
# Krux('set', 'user_attr_omniture_evar32', typeof window.s =='object' &amp;&amp; window.s['eVar32']);
# // Using UrlPath 1 to produce page attribute Level1
# Krux('scrape', { "page_attr_Level1": {url_path: "1"}});
# // Using UrlPath 2 to produce page attribute Level2
# Krux('scrape', { "page_attr_Level2": {url_path: "2"}});
# // Using Cookie DYN_USER_ID to produce user attribute cookie_dyn_user_id
# Krux('scrape', { "user_attr_cookie_dyn_user_id": {cookie: "DYN_USER_ID"}});
# // Using Cookie hid to produce user attribute cookie_hid
# Krux('scrape', { "user_attr_cookie_hid": {cookie: "hid"}});
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18135">
#     <script>
#      (function() {
#   if (window.AR) {
#       var site = AR.Ads.Site;
#       var zone = AR.Ads.Zone;
#       var visitorstatus = AR.Ads.VisitorStatus;
#       var keyvalues = AR.Ads.KeyValues;
#       var arFriendlyName = AR.FriendlyName;
#
#       if (site) Krux('set', {'page_attr_site': site });
#       if (zone) Krux('set', {'page_attr_zone': zone });
#       if (visitorstatus) Krux('set', {'user_attr_visitorstatus': visitorstatus });
#       if (keyvalues) Krux('set', {'page_attr_keyvalues': keyvalues });
#       if (arFriendlyName) Krux('set', {'page_attr_ar_friendly_name': arFriendlyName });
#   }
#   if (window.s) {
#       var evar11 = s.eVar11;
#       if (evar11 !=null &amp;&amp; evar11 != "") Krux('set', {'page_attr_evar11': evar11 });
#   }
# })();
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18209">
#     <script>
#      (function() {
# 	var currentDateTime = (window.Krux &amp;&amp; Krux('get', 'now'))  || new Date();
# 	var DAYSOFWEEK = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'];
# 	var currentDateOfMonth = currentDateTime.getDate();
# 	var currentDay =  DAYSOFWEEK[currentDateTime.getDay()];
#         var currentTimePeriod;
#
# 	if (currentDateTime.getHours() &lt; 12) {
# 		currentTimePeriod = "Morning";
# 	} else if (currentDateTime.getHours() &gt;= 12 &amp;&amp; currentDateTime.getHours() &lt;= 17) {
# 		currentTimePeriod = "Afternoon";
# 	} else if (currentDateTime.getHours() &gt; 17 &amp;&amp; currentDateTime.getHours() &lt;= 20) {
# 		currentTimePeriod = "Evening";
# 	} else if(currentDateTime.getHours() &gt; 20 &amp;&amp; currentDateTime.getHours() &lt;= 24) {
# 		currentTimePeriod = "Night";
# 	}
#
#
# 	if(currentDateOfMonth) {Krux('set','user_attr_visitor_date_of_month', currentDateOfMonth);}
# 	if(currentDay) {Krux('set', 'user_attr_visitor_day_of_week', currentDay);}
# 	if(currentTimePeriod) {Krux('set', 'user_attr_visitor_time_of_day', currentTimePeriod);}
#
# }());
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="20530">
#     <script src="http://cdn.selectablemedia.com/tg/p/ioRpChND/js/sm_uber.js">
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="18269">
#     <script>
#      (function() {
#
#   var pageViews = Krux('require:store').get('kxtag67244.day');
#
#   if (pageViews == "1") {
#      var prefix = location.protocol == "https:" ? "https:" : "http:";
#      var kurl = prefix + "//beacon.krxd.net/event.gif?event_id=KB6pFLRs&amp;event_type=cact";
#      var i = new Image();
#      i.src = kurl;
#   }
#
# })();
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="26796">
#     <script>
#      (function(){
#     var dataObj = Krux('scrape.js_global', 'dataLayer'),
#         userKeys = 'user',
#         omitKeys = 'undefined',
#         custDelimit = 'false',
#         prefix = 'undefined_',
#         config = {
#             'userKeys': userKeys ? userKeys.split(',') : undefined,
#             'omitKeys': omitKeys ? omitKeys.split(',') : [],
#             'customDelimited': custDelimit ? custDelimit.split(',') : undefined,
#             'caseSensitive': 'false' === 'true',
#             'useFullPath': 'false' === 'true',
#             'useLastValue': 'false' === 'true',
#             'convertAttrNames': []
#         };
#     if (!prefix.match(/^$|null|undefined|false/)) {
#         config.convertAttrNames.push({
#             pattern: /((?:page|user)_attr_)/,
#             replacement: '$1' + prefix
#         });
#     }
#     config.omitKeys.push(/gtm\./);
#     Krux('ingestDataLayer', dataObj, config);
#
#  Krux('scrape', {user_attr_omniture_id: { javascript: '  window.adService.pageTargetingValues.oid'}} );
#
#
#
# })();
#     </script>
#    </span>
#   </div>
#  </body>
#  <iframe id="kx-proxy-H1gAR3V7" src="http://cdn.krxd.net/partnerjs/xdi/proxy.3d2100fd7107262ecb55ce6847f01fa5.html#%21kxcid=H1gAR3V7&amp;kxt=http%3A%2F%2Fallrecipes.com&amp;kxcl=cdn&amp;kxp=" style="display: none; visibility: hidden; height: 0; width: 0;">
#  </iframe>
# </html>

# %%
# All the recipes 


# All the recipe titles: 
# [a['href'] for a in soup.select('article.grid-col--fixed-tiles div.ng-scope span.ng-binding')]
[a.text for a in collections.OrderedDict.fromkeys(soup.select('article.grid-col--fixed-tiles div.ng-scope h3.grid-col__h3--recipe-grid a.ng-scope')) if a.text != ' ']
# Out:
# [u' E-Z Drop Biscuits ',
#  u" Mom's Simple Dumplings ",
#  u' No Bake Cookies I ',
#  u' Zucchini Chips ',
#  u' Roasted Brussels Sprouts ',
#  u" Chef John's Scones ",
#  u' Milk Cracker Stuffing ',
#  u' Colored Sugar ',
#  u' Molasses Cookies ',
#  u" Momma's Poor Man's Lasagne ",
#  u' Sugar Cookie Cutouts ',
#  u' Whole Wheat Pumpkin-Applesauce Muffins ',
#  u' Pumpkin Smoothie ',
#  u' Condensed Milk Chocolate Frosting ',
#  u" Michelle's Famous Washed Cranberry Sauce ",
#  u' Chocolate Covered Strawberries ',
#  u' Baked Kale Chips ',
#  u' Eggplant Burgers ',
#  u' Mexican Rice III ',
#  u' Chicken with Stuffing ']

# %%
# Get link / recipe ID 
[a for a in collections.OrderedDict.fromkeys([a.attrs['data-ng-href'] for a in soup.select('article.grid-col--fixed-tiles div.ng-scope h3.grid-col__h3--recipe-grid a.ng-scope')])]
# Out:
# [u'/recipe/21135/e-z-drop-biscuits/',
#  u'/recipe/210083/moms-simple-dumplings/',
#  u'/recipe/9832/no-bake-cookies-i/',
#  u'/recipe/232278/zucchini-chips/',
#  u'/recipe/67952/roasted-brussels-sprouts/',
#  u'/recipe/220994/chef-johns-scones/',
#  u'/recipe/23417/milk-cracker-stuffing/',
#  u'/recipe/24421/colored-sugar/',
#  u'/recipe/9311/molasses-cookies/',
#  u'/recipe/218879/mommas-poor-mans-lasagne/',
#  u'/recipe/15149/sugar-cookie-cutouts/',
#  u'/recipe/55334/whole-wheat-pumpkin-applesauce-muffins/',
#  u'/recipe/142434/pumpkin-smoothie/',
#  u'/recipe/10327/condensed-milk-chocolate-frosting/',
#  u'/recipe/9158/michelles-famous-washed-cranberry-sauce/',
#  u'/recipe/21712/chocolate-covered-strawberries/',
#  u'/recipe/176957/baked-kale-chips/',
#  u'/recipe/53577/eggplant-burgers/',
#  u'/recipe/73303/mexican-rice-iii/',
#  u'/recipe/119947/chicken-with-stuffing/']

# %% [markdown]
# ###### Get link / recipe ID

# %%
list(set([a.attrs['data-ng-href'].split('/')[2] for a in soup.select('article.grid-col--fixed-tiles div.ng-scope h3.grid-col__h3--recipe-grid a.ng-scope')]))

# %%
# To summarize
madeit_names_list = [a.text for a in collections.OrderedDict.fromkeys(soup.select('article.grid-col--fixed-tiles div.ng-scope h3.grid-col__h3--recipe-grid a.ng-scope')) if a.text != ' ']
madeit_recipe_ID_list = [a.split('/')[2] for a in collections.OrderedDict.fromkeys([a.attrs['data-ng-href'] for a in soup.select('article.grid-col--fixed-tiles div.ng-scope h3.grid-col__h3--recipe-grid a.ng-scope')])]
dict(zip(madeit_names_list, madeit_recipe_ID_list))
# Out:
# [(u' Chicken with Stuffing ', u'119947'),
#  (u" Michelle's Famous Washed Cranberry Sauce ", u'9158'),
#  (u" Mom's Simple Dumplings ", u'210083'),
#  (u' Sugar Cookie Cutouts ', u'15149'),
#  (u' E-Z Drop Biscuits ', u'21135'),
#  (u' Chocolate Covered Strawberries ', u'21712'),
#  (u" Chef John's Scones ", u'220994'),
#  (u' No Bake Cookies I ', u'9832'),
#  (u' Mexican Rice III ', u'73303'),
#  (u' Eggplant Burgers ', u'53577'),
#  (u' Milk Cracker Stuffing ', u'23417'),
#  (u" Momma's Poor Man's Lasagne ", u'218879'),
#  (u' Baked Kale Chips ', u'176957'),
#  (u' Zucchini Chips ', u'232278'),
#  (u' Molasses Cookies ', u'9311'),
#  (u' Roasted Brussels Sprouts ', u'67952'),
#  (u' Pumpkin Smoothie ', u'142434'),
#  (u' Colored Sugar ', u'24421'),
#  (u' Condensed Milk Chocolate Frosting ', u'10327'),
#  (u' Whole Wheat Pumpkin-Applesauce Muffins ', u'55334')]

# %%
# FYI: the "more" button for the next page: 
# <button data-ng-click="getItems()" data-ng-disabled="disableMore" data-ng-hide="hideMore" class="btns-one-small--bottom-margin ng-click-active" id="moreBtn">More</button>

# %%
allrecipes_db.command?

# %%
members_coll.find_one().keys()
# Out:
# [u'favorites_page',
#  u'following_page',
#  u'reviews_recipe_id_list',
#  u'reviews_dict',
#  u'reviews_page',
#  u'madeits_recipe_id_list',
#  u'followers_page',
#  u'favorites_dict',
#  u'madeit_page',
#  u'link',
#  u'member_ID',
#  u'favorites_recipe_id_list',
#  u'_id',
#  u'recipes_page',
#  u'madeits_dict']

# %% [markdown]
# ____
# ### Added function to `scraper` class to populate 'made-it' data in database.
# ___

# %%
no_madeitlist_docs_cursor = members_coll.find({"member_ID": {"$exists":True},
                                                "madeits_dict": {"$exists": False}},["member_ID"])

# %%
no_madeitlist_docs_cursor.count()
# Out:
# 0
