# %% [markdown]
# # Scraper for recipes (to migrate to EC2)

# %%
import time
from urllib import urlencode  # TODO(Miles): Python 3
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from bs4 import BeautifulSoup
import random
import requests
import pymongo
import pandas as pd
import re
import pickle
import boto3
import os
import collections
from IPython.display import Image

# %%
# %matplotlib inline

# %%
# Get list of 'recipe_ID's to scrape
recipes_orderedset = pickle.load(open('recipes_orderedset.pkl', 'rb'))

# %%
len(recipes_ordertset)
# Out:
# 9782

# %%
# Access s3 bucket to use 
AWS_KEY = os.environ['AWS_ACCESS_KEY']
AWS_SECRET = os.environ['AWS_SECRET_ACCESS_KEY']

# %%
# Open s3 session with boto3
session = boto3.Session(aws_access_key_id=AWS_KEY, aws_secret_access_key=AWS_SECRET)
s3 = session.resource('s3')

# %%
mybucket = s3.Bucket('ohailolcat')

# %%
mybucket.upload_file?

# %%
# Use Firefox as browser
browser = webdriver.Firefox(firefox_binary=FirefoxBinary(
    firefox_path='/Applications/FirefoxESR.app/Contents/MacOS/firefox'
))

# %%
offset = 0

# %%
for i, a in enumerate(recipes_orderedset.keys()[offset:200]):
    browser.get("http://allrecipes.com/recipe/{}/".format(a))
    print "list item number {}, {} \n  {}\n\n\n".format(i+offset, a, browser.current_url)
#    browser.execute_script("window.scrollTo(0, document.body.scrollHeight/1.2);")
    time.sleep(2 + random.random() * 5)
    browser.save_screenshot('recipe_{}.png'.format(a)) 
    mybucket.upload_file('recipe_{}.png'.format(a), 'recipes/recipe_{}.png'.format(a))
    with open("recipe_{}.pkl".format(a), 'wb') as f: pickle.dump(browser.page_source, f)
    mybucket.upload_file('recipe_{}.pkl'.format(a), 'recipes/recipe_{}.pkl'.format(a))
# Out:
# list item number 0, 228056
#   http://allrecipes.com/recipe/228056/parmesan-crusted-tilapia-fillets/
#
#
#
# list item number 1, 16073
#   http://allrecipes.com/recipe/16073/potato-latkes-i/
#
#
#
# list item number 2, 241213
#   http://allrecipes.com/recipe/241213/hard-steamed-eggs/
#
#
#
# list item number 3, 23998
#   http://allrecipes.com/recipe/23998/a-good-easy-garlic-chicken/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-407a874f0a9d> in <module>()
#       6     time.sleep(2 + random.random() * 5)
#       7     browser.save_screenshot('recipe_{}.png'.format(a))
# ----> 8     mybucket.upload_file('recipe_{}.png'.format(a), '/recipes/recipe_{}.png'.format(a))
#       9     with open("recipe_{}.pkl".format(a), 'wb') as f: pickle.dump(browser.page_source, f)
#      10     mybucket.upload_file('recipe_{}.pkl'.format(a), '/recipes/recipe_{}.pkl'.format(a))
#
# /Users/User1/anaconda/envs/python2/lib/python2.7/site-packages/boto3/s3/inject.pyc in bucket_upload_file(self, Filename, Key, ExtraArgs, Callback, Config)
#     143     return self.meta.client.upload_file(
#     144         Filename=Filename, Bucket=self.name, Key=Key,
# --> 145         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#     146
#     147
#
# /Users/User1/anaconda/envs/python2/lib/python2.7/site-packages/boto3/s3/inject.pyc in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     104         return transfer.upload_file(
#     105             filename=Filename, bucket=Bucket, key=Key,
# --> 106             extra_args=ExtraArgs, callback=Callback)
#     107
#     108
#
# /Users/User1/anaconda/envs/python2/lib/python2.7/site-packages/boto3/s3/transfer.pyc in upload_file(self, filename, bucket, key, callback, extra_args)
#     273             filename, bucket, key, extra_args, subscribers)
#     274         try:
# --> 275             future.result()
#     276         # If a client error was raised, add the backwards compatibility layer
#     277         # that raises a S3UploadFailedError. These specific errors were only
#
# /Users/User1/anaconda/envs/python2/lib/python2.7/site-packages/s3transfer/futures.pyc in result(self)
#      74         except KeyboardInterrupt as e:
#      75             self.cancel()
# ---> 76             raise e
#      77
#      78     def cancel(self):
#
# KeyboardInterrupt:

# %%
browser.quit()

# %%
pwd
# Out:
# u'/Users/User1/DS/projects/food/src/data'

# %%
ls
# Out:
# __init__.py                        recipe_16073.pkl
# aboutme.pkl                        recipe_16073.png
# aboutme2.pkl                       recipe_228056.pkl
# aboutme_page.ipynb                 recipe_228056.png
# favorites_page.ipynb               recipe_23998.png
# followers_page.ipynb               recipe_241213.pkl
# following_page.ipynb               recipe_241213.png
# geckodriver.log                    recipe_scrape_list.ipynb
# lookit.py                          recipe_scraper-localmachine.ipynb
# madeit_page.ipynb                  recipes_orderedset.pkl
# mem.py                             reviews_page.ipynb
# members.py                         scrape_for_reviews.py
# memlist.txt                        scrape_for_reviews.pyc
# ndb_to_mongo.py                    txt_to_mongo.py
# ndb_to_mongo.pyc                   ubuntu@54.202.196.138
# non-allrecipe reviews.ipynb        usda_food_items.ipynb

# %%
Image("recipe_16073.png")

# %%
Image
