# %%
# Populate documents in recipes_coll with new scraped pages in recipe_pages_coll

# %%
import pymongo 
import sys 
sys.path.insert(0,'../..')
import main

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
allrecipes_db = client.allrecipes 
recipes_coll = allrecipes_db.recipes
recipe_pages_coll = allrecipes_db.recipe_pages

# %%
parser1 = main.Parser()
# Out:
# Connected to Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'allrecipes')

# %%
parser1.get_recipe_data_from_recipe_pages_coll()
# Out:
# Number of docs in recipe_pages_coll 2088
# Number of docs in recipe_pages with ingredients info: 8876
# Number of documents to populate: 2088
# upserting:  73468
# upserting:  22469
# upserting:  220091
# upserting:  14196
# upserting:  16071
# upserting:  170446
# upserting:  220094
# upserting:  19715
# upserting:  86362
# upserting:  72427
# upserting:  239042
# upserting:  76964
# upserting:  258398
# upserting:  239046
# upserting:  35781
# upserting:  117676
# upserting:  239049
# upserting:  33641
# upserting:  256906
# upserting:  221142
# upserting:  255344
# upserting:  214897
# upserting:  256908
# upserting:  220766
# upserting:  220765
# upserting:  239445
# upserting:  241678
# upserting:  214079
# upserting:  220167
# upserting:  180294
# upserting:  214072
# upserting:  75545
# upserting:  241325
# upserting:  16675
# upserting:  241451
# upserting:  240104
# upserting:  25068
# upserting:  56236
# upserting:  240101
# upserting:  73269
# upserting:  244483
# upserting:  63603073
# upserting:  239280
# upserting:  244245
# upserting:  235387
# upserting:  102197
# upserting:  240581
# upserting:  215780
# upserting:  6794
# upserting:  13600
# upserting:  205117
# upserting:  205116
# upserting:  235145
# upserting:  13609
# upserting:  235146
# upserting:  64597362
# upserting:  25665
# upserting:  215412
# upserting:  240616
# upserting:  240619
# upserting:  120723
# upserting:  69882
# upserting:  75947
# upserting:  21100
# upserting:  21105
# upserting:  11544
# upserting:  106357
# upserting:  17659
# upserting:  240039
# upserting:  36203
# upserting:  17388
# upserting:  241525
# upserting:  240031
# upserting:  17380
# upserting:  25447
# upserting:  17387
# upserting:  245822
# upserting:  12016
# upserting:  26395
# upserting:  219893
# upserting:  16385
# upserting:  26393
# upserting:  17251
# upserting:  97449
# upserting:  221963
# upserting:  221960
# upserting:  17035
# upserting:  235967
# upserting:  62620611
# upserting:  24881
# upserting:  46790
# upserting:  49564
# upserting:  168881
# upserting:  244669
# upserting:  45688
# upserting:  235562
# upserting:  254451
# upserting:  235567
# upserting:  258159
# upserting:  6762
# upserting:  212824
# upserting:  244468
# upserting:  254294
# upserting:  38399
# upserting:  69172
# upserting:  46645
# upserting:  42492
# upserting:  21297
# upserting:  234685
# upserting:  26028
# upserting:  12127
# upserting:  14138
# upserting:  9340
# upserting:  53603
# upserting:  10147
# upserting:  10149
# upserting:  236817
# upserting:  218376
# upserting:  17729
# upserting:  64594866
# upserting:  16925
# upserting:  8943
# upserting:  236727
# upserting:  255071
# upserting:  7265
# upserting:  247264
# upserting:  85055
# upserting:  90314
# upserting:  141050
# upserting:  85501
# upserting:  12239
# upserting:  220891
# upserting:  14620
# upserting:  234510
# upserting:  15714
# upserting:  15862
# upserting:  9745
# upserting:  38647
# upserting:  175798
# upserting:  238896
# upserting:  10568
# upserting:  80974
# upserting:  49948
# upserting:  24155
# upserting:  216330
# upserting:  256298
# upserting:  237034
# upserting:  189590
# upserting:  246221
# upserting:  219156
# upserting:  7144
# upserting:  75073
# upserting:  62572924
# upserting:  18921
# upserting:  8836
# upserting:  210409
# upserting:  220875
# upserting:  232006
# upserting:  244527
# upserting:  142777
# upserting:  142776
# upserting:  238090
# upserting:  172367
# upserting:  169118
# upserting:  86695
# upserting:  17970
# upserting:  217861
# upserting:  234955
# upserting:  143082
# upserting:  171094
# upserting:  14718
# upserting:  24231
# upserting:  15660
# upserting:  14249
# upserting:  233289
# upserting:  218798
# upserting:  234427
# upserting:  220948
# upserting:  222314
# upserting:  237450
# upserting:  216798
# upserting:  218557
# upserting:  216795
# upserting:  216021
# upserting:  255490
# upserting:  132833
# upserting:  13949
# upserting:  132127
# upserting:  15910
# upserting:  35151
# upserting:  16682
# upserting:  36002
# upserting:  217266
# upserting:  242140
# upserting:  209928
# upserting:  76089
# upserting:  256631
# upserting:  256633
# upserting:  256636
# upserting:  123382
# upserting:  228334
# upserting:  83097
# upserting:  12681
# upserting:  14402
# upserting:  229553
# upserting:  64548072
# upserting:  233603
# upserting:  72126
# upserting:  63794528
# upserting:  239871
# upserting:  257232
# upserting:  234374
# upserting:  228930
# upserting:  14883
# upserting:  214669
# upserting:  13831
# upserting:  8388
# upserting:  245037
# upserting:  245032
# upserting:  143064
# upserting:  8381
# upserting:  159432
# upserting:  173309
# upserting:  12830
# upserting:  8549
# upserting:  258018
# upserting:  109190
# upserting:  258017
# upserting:  216805
# upserting:  7456
# upserting:  24411
# upserting:  257657
# upserting:  26626
# upserting:  15047
# upserting:  221371
# upserting:  213146
# upserting:  184197
# upserting:  48952
# upserting:  155130
# upserting:  184193
# upserting:  230646
# upserting:  89851
# upserting:  8491
# upserting:  8490
# upserting:  8497
# upserting:  258494
# upserting:  219442
# upserting:  72381
# upserting:  50410
# upserting:  64527381
# upserting:  242075
# upserting:  103971
# upserting:  223203
# upserting:  228067
# upserting:  73470
# upserting:  245256
# upserting:  64464672
# upserting:  13724
# upserting:  228846
# upserting:  239056
# upserting:  12878
# upserting:  239052
# upserting:  214796
# upserting:  221153
# upserting:  244816
# upserting:  231608
# upserting:  197842
# upserting:  256915
# upserting:  19380
# upserting:  231603
# upserting:  240828
# upserting:  240829
# upserting:  69413
# upserting:  64504099
# upserting:  228443
# upserting:  239907
# upserting:  7521
# upserting:  91511
# upserting:  24709
# upserting:  110941
# upserting:  241662
# upserting:  7528
# upserting:  239458
# upserting:  180576
# upserting:  16663
# upserting:  86963
# upserting:  241330
# upserting:  215332
# upserting:  240137
# upserting:  214085
# upserting:  241684
# upserting:  18890
# upserting:  142807
# upserting:  77020
# upserting:  12714
# upserting:  214082
# upserting:  70824
# upserting:  12719
# upserting:  214088
# upserting:  77758
# upserting:  23873
# upserting:  23874
# upserting:  6789
# upserting:  235172
# upserting:  258239
# upserting:  26498
# upserting:  25612
# upserting:  56136
# upserting:  64624620
# upserting:  215932
# upserting:  240623
# upserting:  46490
# upserting:  257520
# upserting:  62362247
# upserting:  124619
# upserting:  57264
# upserting:  16485
# upserting:  220447
# upserting:  240558
# upserting:  13531
# upserting:  241676
# upserting:  219932
# upserting:  25433
# upserting:  25432
# upserting:  51850
# upserting:  236555
# upserting:  241530
# upserting:  38622
# upserting:  204890
# upserting:  235776
# upserting:  11752
# upserting:  22490
# upserting:  246757
# upserting:  124299
# upserting:  246206
# upserting:  223027
# upserting:  85337
# upserting:  159365
# upserting:  19565
# upserting:  161919
# upserting:  101530
# upserting:  64510099
# upserting:  119857
# upserting:  257865
# upserting:  221975
# upserting:  20881
# upserting:  246418
# upserting:  9243
# upserting:  62349254
# upserting:  235916
# upserting:  20889
# upserting:  25544
# upserting:  62620193
# upserting:  24895
# upserting:  7858
# upserting:  60011
# upserting:  244475
# upserting:  233226
# upserting:  223157
# upserting:  167052
# upserting:  236153
# upserting:  223153
# upserting:  162024
# upserting:  185675
# upserting:  235594
# upserting:  13441
# upserting:  9403
# upserting:  11622
# upserting:  254281
# upserting:  104657
# upserting:  46654
# upserting:  46307
# upserting:  9409
# upserting:  26030
# upserting:  10626
# upserting:  24096
# upserting:  134154
# upserting:  238232
# upserting:  20088
# upserting:  236804
# upserting:  231855
# upserting:  236806
# upserting:  48553
# upserting:  64429532
# upserting:  158703
# upserting:  222171
# upserting:  219649
# upserting:  200771
# upserting:  160241
# upserting:  21738
# upserting:  21739
# upserting:  247090
# upserting:  247091
# upserting:  72673
# upserting:  211541
# upserting:  21736
# upserting:  7216
# upserting:  13194
# upserting:  12226
# upserting:  80565
# upserting:  10711
# upserting:  36781
# upserting:  85517
# upserting:  232250
# upserting:  125528
# upserting:  62802694
# upserting:  217156
# upserting:  14877
# upserting:  70830
# upserting:  14659
# upserting:  64408711
# upserting:  14878
# upserting:  257532
# upserting:  20468
# upserting:  245453
# upserting:  219143
# upserting:  238883
# upserting:  239541
# upserting:  240033
# upserting:  20467
# upserting:  246238
# upserting:  21425
# upserting:  24140
# upserting:  216656
# upserting:  246233
# upserting:  256285
# upserting:  168852
# upserting:  155190
# upserting:  202825
# upserting:  211127
# upserting:  176216
# upserting:  12954
# upserting:  15676
# upserting:  232749
# upserting:  59951
# upserting:  237992
# upserting:  15678
# upserting:  237996
# upserting:  233295
# upserting:  217872
# upserting:  245100
# upserting:  14275
# upserting:  64493472
# upserting:  17830
# upserting:  7665
# upserting:  7664
# upserting:  233299
# upserting:  80819
# upserting:  246125
# upserting:  169583
# upserting:  143168
# upserting:  242314
# upserting:  62420099
# upserting:  220930
# upserting:  143166
# upserting:  223491
# upserting:  154821
# upserting:  146100
# upserting:  237468
# upserting:  232109
# upserting:  64534202
# upserting:  218521
# upserting:  68611
# upserting:  231470
# upserting:  34419
# upserting:  65478
# upserting:  242130
# upserting:  233504
# upserting:  237868
# upserting:  15908
# upserting:  242427
# upserting:  18156
# upserting:  11233
# upserting:  256628
# upserting:  256625
# upserting:  256624
# upserting:  91674
# upserting:  238547
# upserting:  239848
# upserting:  230082
# upserting:  7192
# upserting:  239842
# upserting:  216930
# upserting:  217306
# upserting:  79701
# upserting:  232812
# upserting:  24740
# upserting:  163998
# upserting:  64571267
# upserting:  228927
# upserting:  234347
# upserting:  232818
# upserting:  232819
# upserting:  245020
# upserting:  213685
# upserting:  238469
# upserting:  238468
# upserting:  169136
# upserting:  52461
# upserting:  238461
# upserting:  34523
# upserting:  64499898
# upserting:  12820
# upserting:  8535
# upserting:  9980
# upserting:  8025
# upserting:  14504
# upserting:  63668876
# upserting:  212482
# upserting:  26630
# upserting:  92525
# upserting:  239599
# upserting:  86649
# upserting:  231488
# upserting:  25958
# upserting:  64527374
# upserting:  239607
# upserting:  143432
# upserting:  64527378
# upserting:  219450
# upserting:  174342
# upserting:  25957
# upserting:  213196
# upserting:  93770
# upserting:  95992
# upserting:  221520
# upserting:  35210
# upserting:  74722
# upserting:  228071
# upserting:  223233
# upserting:  40092
# upserting:  64581466
# upserting:  218899
# upserting:  238511
# upserting:  238510
# upserting:  8443
# upserting:  239023
# upserting:  228585
# upserting:  22647
# upserting:  77107
# upserting:  22397
# upserting:  239025
# upserting:  13996
# upserting:  64536420
# upserting:  77297
# upserting:  220149
# upserting:  239930
# upserting:  35854
# upserting:  228452
# upserting:  26825
# upserting:  206817
# upserting:  22246
# upserting:  213510
# upserting:  63973083
# upserting:  241834
# upserting:  218092
# upserting:  218093
# upserting:  241027
# upserting:  16659
# upserting:  201097
# upserting:  214508
# upserting:  16655
# upserting:  16654
# upserting:  63968008
# upserting:  235166
# upserting:  235165
# upserting:  77030
# upserting:  62181249
# upserting:  223302
# upserting:  141326
# upserting:  231105
# upserting:  231104
# upserting:  19285
# upserting:  220326
# upserting:  258223
# upserting:  23865
# upserting:  52934
# upserting:  116602
# upserting:  11298
# upserting:  241231
# upserting:  214432
# upserting:  214433
# upserting:  16018
# upserting:  55639
# upserting:  65671
# upserting:  11295
# upserting:  220459
# upserting:  240544
# upserting:  116322
# upserting:  21122
# upserting:  98442
# upserting:  24952
# upserting:  19919
# upserting:  13521
# upserting:  223010
# upserting:  75458
# upserting:  150591
# upserting:  222544
# upserting:  63692021
# upserting:  19914
# upserting:  245857
# upserting:  25425
# upserting:  235761
# upserting:  205626
# upserting:  215695
# upserting:  215692
# upserting:  64556453
# upserting:  159374
# upserting:  215325
# upserting:  69995
# upserting:  240123
# upserting:  69993
# upserting:  220218
# upserting:  63912
# upserting:  101522
# upserting:  6686
# upserting:  240946
# upserting:  64054731
# upserting:  9508
# upserting:  20895
# upserting:  257873
# upserting:  213255
# upserting:  141585
# upserting:  235904
# upserting:  221943
# upserting:  16345
# upserting:  16347
# upserting:  117195
# upserting:  64534212
# upserting:  13290
# upserting:  247403
# upserting:  75671
# upserting:  17292
# upserting:  64185337
# upserting:  12107
# upserting:  244448
# upserting:  254470
# upserting:  13451
# upserting:  7990
# upserting:  7995
# upserting:  57071
# upserting:  11630
# upserting:  26047
# upserting:  22299
# upserting:  20098
# upserting:  231828
# upserting:  9610
# upserting:  246680
# upserting:  45641
# upserting:  255380
# upserting:  247241
# upserting:  58058
# upserting:  222167
# upserting:  247246
# upserting:  13182
# upserting:  255386
# upserting:  197470
# upserting:  218318
# upserting:  222169
# upserting:  191159
# upserting:  13189
# upserting:  17745
# upserting:  255011
# upserting:  16901
# upserting:  232244
# upserting:  232243
# upserting:  134094
# upserting:  219219
# upserting:  64530043
# upserting:  64530040
# upserting:  64530041
# upserting:  222768
# upserting:  36823
# upserting:  236239
# upserting:  236234
# upserting:  139044
# upserting:  13896
# upserting:  236907
# upserting:  58233
# upserting:  133034
# upserting:  14649
# upserting:  14868
# upserting:  219132
# upserting:  246205
# upserting:  14082
# upserting:  38624
# upserting:  14089
# upserting:  64512772
# upserting:  53574
# upserting:  20474
# upserting:  237050
# upserting:  9295
# upserting:  216641
# upserting:  7338
# upserting:  64641290
# upserting:  146459
# upserting:  236050
# upserting:  112206
# upserting:  12923
# upserting:  18093
# upserting:  232750
# upserting:  230080
# upserting:  18097
# upserting:  238073
# upserting:  230085
# upserting:  208701
# upserting:  14264
# upserting:  64562440
# upserting:  222378
# upserting:  238989
# upserting:  219681
# upserting:  217842
# upserting:  14263
# upserting:  20076
# upserting:  160051
# upserting:  156635
# upserting:  180813
# upserting:  219048
# upserting:  62623777
# upserting:  79023
# upserting:  161586
# upserting:  63551390
# upserting:  18389
# upserting:  18387
# upserting:  64100358
# upserting:  232115
# upserting:  237474
# upserting:  232112
# upserting:  223480
# upserting:  24380
# upserting:  231448
# upserting:  6996
# upserting:  231447
# upserting:  257700
# upserting:  24544
# upserting:  238182
# upserting:  238181
# upserting:  16022
# upserting:  26738
# upserting:  17997
# upserting:  52635
# upserting:  25898
# upserting:  239852
# upserting:  180977
# upserting:  11101
# upserting:  79286
# upserting:  219596
# upserting:  241795
# upserting:  222204
# upserting:  212741
# upserting:  238324
# upserting:  13851
# upserting:  13855
# upserting:  239104
# upserting:  239107
# upserting:  229442
# upserting:  228910
# upserting:  188361
# upserting:  234350
# upserting:  230661
# upserting:  165102
# upserting:  12583
# upserting:  256738
# upserting:  12852
# upserting:  9994
# upserting:  12856
# upserting:  228262
# upserting:  217193
# upserting:  25964
# upserting:  14512
# upserting:  16754
# upserting:  14511
# upserting:  213165
# upserting:  64642548
# upserting:  220648
# upserting:  239614
# upserting:  94582
# upserting:  62780692
# upserting:  64595422
# upserting:  72878
# upserting:  245651
# upserting:  64644066
# upserting:  65066
# upserting:  56312
# upserting:  22658
# upserting:  228004
# upserting:  180150
# upserting:  258454
# upserting:  258455
# upserting:  26540
# upserting:  258453
# upserting:  8450
# upserting:  17374
# upserting:  218885
# upserting:  229848
# upserting:  101732
# upserting:  15336
# upserting:  39153
# upserting:  220134
# upserting:  13985
# upserting:  60923
# upserting:  60924
# upserting:  22258
# upserting:  241828
# upserting:  50050
# upserting:  229993
# upserting:  241041
# upserting:  24763
# upserting:  63280981
# upserting:  213506
# upserting:  16648
# upserting:  64515888
# upserting:  120397
# upserting:  64643840
# upserting:  241319
# upserting:  213236
# upserting:  16135
# upserting:  74847
# upserting:  63815979
# upserting:  213230
# upserting:  239327
# upserting:  118177
# upserting:  86245
# upserting:  131523
# upserting:  150290
# upserting:  145162
# upserting:  63836110
# upserting:  12737
# upserting:  154602
# upserting:  258211
# upserting:  258212
# upserting:  258215
# upserting:  10999
# upserting:  6767
# upserting:  231139
# upserting:  166107
# upserting:  220681
# upserting:  6760
# upserting:  55641
# upserting:  177619
# upserting:  73902
# upserting:  24610
# upserting:  241952
# upserting:  65663
# upserting:  232268
# upserting:  219914
# upserting:  12680
# upserting:  150741
# upserting:  234354
# upserting:  25413
# upserting:  215777
# upserting:  208383
# upserting:  120576
# upserting:  116358
# upserting:  116359
# upserting:  219919
# upserting:  223003
# upserting:  223005
# upserting:  231050
# upserting:  16220
# upserting:  222574
# upserting:  241557
# upserting:  32065
# upserting:  240974
# upserting:  64631539
# upserting:  172747
# upserting:  42554
# upserting:  46078
# upserting:  102235
# upserting:  165256
# upserting:  120157
# upserting:  86394
# upserting:  241953
# upserting:  19584
# upserting:  230875
# upserting:  19582
# upserting:  220267
# upserting:  220596
# upserting:  221959
# upserting:  222686
# upserting:  20865
# upserting:  254392
# upserting:  247438
# upserting:  221955
# upserting:  221954
# upserting:  64538460
# upserting:  19837
# upserting:  16822
# upserting:  64538463
# upserting:  19832
# upserting:  19830
# upserting:  258031
# upserting:  122540
# upserting:  17511
# upserting:  35640
# upserting:  240377
# upserting:  240374
# upserting:  16114
# upserting:  236133
# upserting:  34531
# upserting:  25095
# upserting:  13460
# upserting:  12854
# upserting:  46679
# upserting:  235339
# upserting:  16110
# upserting:  235330
# upserting:  238699
# upserting:  26056
# upserting:  100822
# upserting:  246324
# upserting:  9357
# upserting:  244187
# upserting:  49885
# upserting:  48571930
# upserting:  134137
# upserting:  70589
# upserting:  9191
# upserting:  7945
# upserting:  240204
# upserting:  64330672
# upserting:  244188
# upserting:  21718
# upserting:  217196
# upserting:  75086
# upserting:  22823
# upserting:  17178
# upserting:  21248
# upserting:  222191
# upserting:  222750
# upserting:  8999
# upserting:  42172
# upserting:  222759
# upserting:  26604
# upserting:  64530051
# upserting:  221887
# upserting:  64530052
# upserting:  167419
# upserting:  64224148
# upserting:  235932
# upserting:  64220724
# upserting:  45521
# upserting:  236223
# upserting:  198771
# upserting:  69198
# upserting:  20913
# upserting:  14673
# upserting:  62448402
# upserting:  200620
# upserting:  240422
# upserting:  53560
# upserting:  70698
# upserting:  164512
# upserting:  232588
# upserting:  237065
# upserting:  13087
# upserting:  83448
# upserting:  179285
# upserting:  21403
# upserting:  64401276
# upserting:  199579
# upserting:  242432
# upserting:  26835
# upserting:  76348
# upserting:  257466
# upserting:  257467
# upserting:  257465
# upserting:  257468
# upserting:  257469
# upserting:  76346
# upserting:  222360
# upserting:  10204
# upserting:  7046
# upserting:  14211
# upserting:  14210
# upserting:  27838
# upserting:  220919
# upserting:  122138
# upserting:  233747
# upserting:  256398
# upserting:  14180
# upserting:  10198
# upserting:  64555223
# upserting:  164205
# upserting:  232691
# upserting:  237406
# upserting:  255609
# upserting:  232164
# upserting:  232697
# upserting:  233569
# upserting:  229619
# upserting:  254865
# upserting:  230181
# upserting:  231450
# upserting:  231457
# upserting:  237883
# upserting:  64641571
# upserting:  219587
# upserting:  24575
# upserting:  92433
# upserting:  24572
# upserting:  220860
# upserting:  220861
# upserting:  222219
# upserting:  220865
# upserting:  220867
# upserting:  256641
# upserting:  216297
# upserting:  234508
# upserting:  256642
# upserting:  191950
# upserting:  16371
# upserting:  68925
# upserting:  157825
# upserting:  216109
# upserting:  218618
# upserting:  229505
# upserting:  47823
# upserting:  223588
# upserting:  47821
# upserting:  258027
# upserting:  235642
# upserting:  77346
# upserting:  229272
# upserting:  258022
# upserting:  258021
# upserting:  258020
# upserting:  234323
# upserting:  232836
# upserting:  23669
# upserting:  12599
# upserting:  118785
# upserting:  258028
# upserting:  40448
# upserting:  8837
# upserting:  14522
# upserting:  14521
# upserting:  14520
# upserting:  218043
# upserting:  180705
# upserting:  235645
# upserting:  26611
# upserting:  213758
# upserting:  258107
# upserting:  151379
# upserting:  73843
# upserting:  170061
# upserting:  64475941
# upserting:  64475940
# upserting:  213754
# upserting:  245314
# upserting:  228875
# upserting:  32478
# upserting:  241149
# upserting:  22629
# upserting:  241144
# upserting:  23254
# upserting:  228016
# upserting:  258111
# upserting:  15141
# upserting:  47008
# upserting:  236443
# upserting:  23719
# upserting:  238537
# upserting:  216929
# upserting:  64638665
# upserting:  23715
# upserting:  232907
# upserting:  8192
# upserting:  241813
# upserting:  220129
# upserting:  220128
# upserting:  27005
# upserting:  244840
# upserting:  256415
# upserting:  15328
# upserting:  24758
# upserting:  23392
# upserting:  103347
# upserting:  241039
# upserting:  24598
# upserting:  239486
# upserting:  100839
# upserting:  240781
# upserting:  244201
# upserting:  215585
# upserting:  244205
# upserting:  32611
# upserting:  241360
# upserting:  233980
# upserting:  230461
# upserting:  230462
# upserting:  228491
# upserting:  235107
# upserting:  117749
# upserting:  64125577
# upserting:  64441526
# upserting:  13649
# upserting:  118764
# upserting:  23808
# upserting:  13886
# upserting:  166448
# upserting:  258209
# upserting:  258207
# upserting:  6753
# upserting:  6750
# upserting:  25628
# upserting:  56479
# upserting:  241963
# upserting:  221053
# upserting:  24624
# upserting:  213408
# upserting:  9948
# upserting:  64612873
# upserting:  214182
# upserting:  240807
# upserting:  16212
# upserting:  75473
# upserting:  57783
# upserting:  17344
# upserting:  17613
# upserting:  230994
# upserting:  240560
# upserting:  16584
# upserting:  16581
# upserting:  214168
# upserting:  218187
# upserting:  178498
# upserting:  220585
# upserting:  26806
# upserting:  220582
# upserting:  26192
# upserting:  23938
# upserting:  12698
# upserting:  220278
# upserting:  244196
# upserting:  25711
# upserting:  159357
# upserting:  230860
# upserting:  140617
# upserting:  194071
# upserting:  17500
# upserting:  222694
# upserting:  20703
# upserting:  191793
# upserting:  36371
# upserting:  53887
# upserting:  21090
# upserting:  240360
# upserting:  240362
# upserting:  121361
# upserting:  215167
# upserting:  200296
# upserting:  245916
# upserting:  192591
# upserting:  236106
# upserting:  236452
# upserting:  236103
# upserting:  26266
# upserting:  166847
# upserting:  125864
# upserting:  214648
# upserting:  257299
# upserting:  46530
# upserting:  215026
# upserting:  85493
# upserting:  62899796
# upserting:  122725
# upserting:  57326
# upserting:  246359
# upserting:  9362
# upserting:  235811
# upserting:  218338
# upserting:  52572
# upserting:  21276
# upserting:  237677
# upserting:  237676
# upserting:  22831
# upserting:  10340
# upserting:  9161
# upserting:  64302
# upserting:  10696
# upserting:  255038
# upserting:  222749
# upserting:  94113
# upserting:  222744
# upserting:  16964
# upserting:  21261
# upserting:  9560
# upserting:  46990
# upserting:  64427708
# upserting:  53779
# upserting:  235924
# upserting:  235928
# upserting:  12275
# upserting:  64582392
# upserting:  10740
# upserting:  53224
# upserting:  256098
# upserting:  104804
# upserting:  64132394
# upserting:  11834
# upserting:  218558
# upserting:  11832
# upserting:  121036
# upserting:  201081
# upserting:  182157
# upserting:  246779
# upserting:  219116
# upserting:  223570
# upserting:  187448
# upserting:  219112
# upserting:  8871
# upserting:  121587
# upserting:  8875
# upserting:  121583
# upserting:  14995
# upserting:  232593
# upserting:  68002
# upserting:  54688
# upserting:  13092
# upserting:  24116
# upserting:  167331
# upserting:  11900
# upserting:  90044
# upserting:  168042
# upserting:  84706
# upserting:  81565
# upserting:  36110
# upserting:  18413
# upserting:  18411
# upserting:  199581
# upserting:  237095
# upserting:  176957
# upserting:  86416
# upserting:  237096
# upserting:  86410
# upserting:  230262
# upserting:  237093
# upserting:  230260
# upserting:  238050
# upserting:  81972
# upserting:  123290
# upserting:  238054
# upserting:  15621
# upserting:  255500
# upserting:  10232
# upserting:  58499
# upserting:  122455
# upserting:  7034
# upserting:  13313
# upserting:  58493
# upserting:  63408584
# upserting:  220909
# upserting:  58367
# upserting:  68641
# upserting:  78023
# upserting:  20059
# upserting:  24023
# upserting:  83388
# upserting:  83387
# upserting:  14193
# upserting:  87389
# upserting:  218518
# upserting:  158938
# upserting:  46232
# upserting:  14194
# upserting:  179673
# upserting:  46981
# upserting:  83549
# upserting:  255615
# upserting:  237411
# upserting:  237413
# upserting:  72631
# upserting:  233170
# upserting:  68868
# upserting:  183288
# upserting:  40216
# upserting:  119581
# upserting:  15486
# upserting:  233799
# upserting:  14440
# upserting:  41637
# upserting:  15138
# upserting:  72985
# upserting:  14445
# upserting:  18344
# upserting:  7784
# upserting:  15134
# upserting:  222228
# upserting:  242216
# upserting:  14685
# upserting:  216289
# upserting:  79754
# upserting:  24368
# upserting:  14681
# upserting:  17975
# upserting:  77935
# upserting:  7140
# upserting:  143081
# upserting:  220871
# upserting:  246009
# upserting:  223597
# upserting:  63634358
# upserting:  237303
# upserting:  8720
# upserting:  218605
# upserting:  10757
# upserting:  8725
# upserting:  216440
# upserting:  12877
# upserting:  228649
# upserting:  258050
# upserting:  258051
# upserting:  229263
# upserting:  23658
# upserting:  228640
# upserting:  233429
# upserting:  258058
# upserting:  89855
# upserting:  229268
# upserting:  232825
# upserting:  35064
# upserting:  15005
# upserting:  15004
# upserting:  15003
# upserting:  15001
# upserting:  15000
# upserting:  8298
# upserting:  40450
# upserting:  10991
# upserting:  24240
# upserting:  64642560
# upserting:  62986132
# upserting:  180254
# upserting:  14539
# upserting:  50459
# upserting:  230048
# upserting:  7492
# upserting:  219487
# upserting:  7496
# upserting:  228241
# upserting:  14533
# upserting:  229607
# upserting:  8614
# upserting:  245277
# upserting:  238230
# upserting:  233552
# upserting:  14830
# upserting:  91735
# upserting:  126134
# upserting:  17882
# upserting:  8619
# upserting:  239013
# upserting:  22633
# upserting:  232914
# upserting:  234021
# upserting:  239540
# upserting:  217151
# upserting:  170656
# upserting:  241157
# upserting:  239018
# upserting:  214751
# upserting:  217158
# upserting:  11331
# upserting:  64423630
# upserting:  221194
# upserting:  14837
# upserting:  11337
# upserting:  221190
# upserting:  82380
# upserting:  144149
# upserting:  216934
# upserting:  145494
# upserting:  221198
# upserting:  257105
# upserting:  15311
# upserting:  7565
# upserting:  55065
# upserting:  24745
# upserting:  231486
# upserting:  239490
# upserting:  55069
# upserting:  87427
# upserting:  19108
# upserting:  92359
# upserting:  214620
# upserting:  187450
# upserting:  24582
# upserting:  24583
# upserting:  245074
# upserting:  217080
# upserting:  50030
# upserting:  229469
# upserting:  74915
# upserting:  214579
# upserting:  21509
# upserting:  145632
# upserting:  214571
# upserting:  228739
# upserting:  241373
# upserting:  214572
# upserting:  240772
# upserting:  25415
# upserting:  214577
# upserting:  214576
# upserting:  13651
# upserting:  72520
# upserting:  22298
# upserting:  6740
# upserting:  64024826
# upserting:  235136
# upserting:  26293
# upserting:  22522
# upserting:  32597
# upserting:  56464
# upserting:  148071
# upserting:  231158
# upserting:  177630
# upserting:  13890
# upserting:  140512
# upserting:  16733
# upserting:  11242
# upserting:  220068
# upserting:  221512
# upserting:  206174
# upserting:  9959
# upserting:  9958
# upserting:  221043
# upserting:  19034
# upserting:  19035
# upserting:  19033
# upserting:  64223737
# upserting:  16027
# upserting:  19256
# upserting:  32737
# upserting:  220642
# upserting:  117284
# upserting:  19924
# upserting:  233884
# upserting:  19251
# upserting:  75409
# upserting:  155534
# upserting:  62444794
# upserting:  62620402
# upserting:  25160
# upserting:  231030
# upserting:  241777
# upserting:  22749
# upserting:  244508
# upserting:  12045
# upserting:  16599
# upserting:  245858
# upserting:  23903
# upserting:  23902
# upserting:  12685
# upserting:  230520
# upserting:  12689
# upserting:  235002
# upserting:  119765
# upserting:  235005
# upserting:  88278
# upserting:  31833
# upserting:  241487
# upserting:  16115
# upserting:  214285
# upserting:  244182
# upserting:  241483
# upserting:  215379
# upserting:  25767
# upserting:  240174
# upserting:  215375
# upserting:  81141
# upserting:  230854
# upserting:  240354
# upserting:  21643
# upserting:  215624
# upserting:  221994
# upserting:  21862
# upserting:  7813
# upserting:  215620
# upserting:  50896
# upserting:  20843
# upserting:  235799
# upserting:  21649
# upserting:  231466
# upserting:  257825
# upserting:  21080
# upserting:  13403
# upserting:  62163092
# upserting:  21086
# upserting:  222424
# upserting:  25502
# upserting:  25505
# upserting:  25504
# upserting:  63894739
# upserting:  244439
# upserting:  12316
# upserting:  254244
# upserting:  42375
# upserting:  64530219
# upserting:  203936
# upserting:  16685
# upserting:  16687
# upserting:  11669
# upserting:  235485
# upserting:  24967
# upserting:  86283
# upserting:  88817
# upserting:  119960
# upserting:  64330879
# upserting:  257913
# upserting:  257910
# upserting:  124879
# upserting:  10356
# upserting:  246342
# upserting:  246345
# upserting:  20609
# upserting:  46525
# upserting:  17790
# upserting:  53304
# upserting:  215021
# upserting:  25216
# upserting:  52547
# upserting:  25210
# upserting:  246585
# upserting:  236848
# upserting:  208587
# upserting:  7969
# upserting:  10687
# upserting:  10685
# upserting:  236207
# upserting:  25184
# upserting:  70163
# upserting:  237791
# upserting:  223600
# upserting:  25183
# upserting:  223602
# upserting:  16972
# upserting:  16971
# upserting:  13311
# upserting:  232211
# upserting:  116398
# upserting:  236208
# upserting:  46982
# upserting:  200135
# upserting:  12268
# upserting:  64220706
# upserting:  104763
# upserting:  9579
# upserting:  12267
# upserting:  10756
# upserting:  80525
# upserting:  14838
# upserting:  20931
# upserting:  9388
# upserting:  64405996
# upserting:  122021
# upserting:  20934
# upserting:  64536211
# upserting:  10539
# upserting:  14833
# upserting:  20938
# upserting:  11807
# upserting:  11805
# upserting:  77375
# upserting:  219109
# upserting:  219108
# upserting:  216617
# upserting:  125059
# upserting:  8016
# upserting:  18992
# upserting:  14050
# upserting:  8015
# upserting:  168814
# upserting:  83421
# upserting:  14943
# upserting:  22991
# upserting:  236064
# upserting:  221995
# upserting:  8887
# upserting:  21466
# upserting:  21467
# upserting:  63253174
# upserting:  152653
# upserting:  13228
# upserting:  54839
# upserting:  199598
# upserting:  236847
# upserting:  12311
# upserting:  44746
# upserting:  232361
# upserting:  33157
# upserting:  11934
# upserting:  44742
# upserting:  64220677
# upserting:  12918
# upserting:  147395
# upserting:  44562
# upserting:  14231
# upserting:  14230
# upserting:  179714
# upserting:  169789
# upserting:  15633
# upserting:  7454
# upserting:  15636
# upserting:  14238
# upserting:  219077
# upserting:  62212
# upserting:  123135
# upserting:  7025
# upserting:  219070
# upserting:  213145
# upserting:  10226
# upserting:  10221
# upserting:  219079
# upserting:  9397
# upserting:  186081
# upserting:  220593
# upserting:  216058
# upserting:  24033
# upserting:  232143
# upserting:  216726
# upserting:  142382
# upserting:  234080
# upserting:  216051
# upserting:  24292
# upserting:  54788
# upserting:  15836
# upserting:  64534242
# upserting:  64645743
# upserting:  233165
# upserting:  83557
# upserting:  71568
# upserting:  233160
# upserting:  84609
# upserting:  78567
# upserting:  175385
# upserting:  72068
# upserting:  62623786
# upserting:  15940
# upserting:  62623782
# upserting:  15947
# upserting:  39544
# upserting:  14301
# upserting:  64642523
# upserting:  14307
# upserting:  18359
# upserting:  9331
# upserting:  230324
# upserting:  7459
# upserting:  230323
# upserting:  18352
# upserting:  193187
# upserting:  20334
# upserting:  257599
# upserting:  239809
# upserting:  17968
# upserting:  17969
# upserting:  7157
# upserting:  234837
# upserting:  7155
# upserting:  79749
# upserting:  20338
# upserting:  220804
# upserting:  77927
# upserting:  64045053
# upserting:  216438
# upserting:  142700
# upserting:  64561990
# upserting:  233300
# upserting:  232782
# upserting:  142709
# upserting:  232781
# upserting:  258045
# upserting:  258044
# upserting:  258046
# upserting:  233437
# upserting:  24291
# upserting:  23642
# upserting:  47667
# upserting:  23644
# upserting:  143078
# upserting:  233431
# upserting:  15012
# upserting:  9394
# upserting:  15018
# upserting:  257628
# upserting:  64516982
# upserting:  72194
# upserting:  213733
# upserting:  213730
# upserting:  213737
# upserting:  245660
# upserting:  11063
# upserting:  30575
# upserting:  228255
# upserting:  8660
# upserting:  8662
# upserting:  17899
# upserting:  233230
# upserting:  64502572
# upserting:  72662
# upserting:  17891
# upserting:  238959
# upserting:  30578
# upserting:  23734
# upserting:  239571
# upserting:  118693
# upserting:  234015
# upserting:  23732
# upserting:  228819
# upserting:  218854
# upserting:  22351
# upserting:  245258
# upserting:  22353
# upserting:  63757784
# upserting:  27026
# upserting:  213043
# upserting:  11324
# upserting:  216943
# upserting:  20026
# upserting:  100690
# upserting:  27029
# upserting:  111751
# upserting:  55072
# upserting:  230144
# upserting:  217093
# upserting:  217092
# upserting:  19132
# upserting:  245060
# upserting:  234654
# upserting:  234300
# upserting:  234309
# upserting:  18905
# upserting:  85444
# upserting:  221891
# upserting:  31848
# upserting:  38500
# upserting:  256911
# upserting:  257834
# upserting:  256912
# upserting:  11640
# upserting:  116704
# upserting:  25203
# upserting:  16784
# upserting:  218973
# upserting:  13598
# upserting:  64642831
# upserting:  14820
# upserting:  256063
# upserting:  22986
# upserting:  83083
# upserting:  17960
# upserting:  9038
# upserting:  25704
# upserting:  18327
# upserting:  222088
# upserting:  64569487
# upserting:  64530056
# upserting:  238490
# upserting:  67457
# upserting:  11071
# upserting:  8673
# upserting:  258048
# upserting:  23134
# upserting:  8722
# upserting:  231903
# upserting:  240759
# upserting:  240757
# upserting:  161376
# upserting:  231178
# upserting:  204958
# upserting:  76808
# upserting:  231773
# upserting:  160959
# upserting:  221062
# upserting:  64569888
# upserting:  117803
# upserting:  19271
# upserting:  220625
# upserting:  214157
# upserting:  214156
# upserting:  64644973
# upserting:  230780
# upserting:  10804
# upserting:  121330
# upserting:  64562970
# upserting:  21664
# upserting:  245943
# upserting:  245944
# upserting:  11440
# upserting:  26257
# upserting:  140930
# upserting:  246817
# upserting:  246811
# upserting:  205547
# upserting:  21208
# upserting:  222792
# upserting:  16797
# upserting:  13333
# upserting:  70142
# upserting:  244701
# upserting:  25128
# upserting:  230212
# upserting:  90543
# upserting:  14030
# upserting:  105434
# upserting:  85757
# upserting:  7346
# upserting:  25431
# upserting:  62585
# upserting:  17043
# upserting:  21449
# upserting:  17049
# upserting:  7349
# upserting:  232301
# upserting:  13203
# upserting:  64399027
# upserting:  22605
# upserting:  230239
# upserting:  14781
# upserting:  246146
# upserting:  155827
# upserting:  11861
# upserting:  80986
# upserting:  13110
# upserting:  8938
# upserting:  146572
# upserting:  255420
# upserting:  242399
# upserting:  130923
# upserting:  7177
# upserting:  11759
# upserting:  187625
# upserting:  8404
# upserting:  57808
# upserting:  209683
# upserting:  12881
# upserting:  133846
# upserting:  7047
# upserting:  218724
# upserting:  79301
# upserting:  8640
# upserting:  23201
# upserting:  79437
# upserting:  222878
# upserting:  24798
# upserting:  44839
# upserting:  12401
# upserting:  7593
# upserting:  44831
# upserting:  38214
# upserting:  214945
# upserting:  239426
# upserting:  22572
# upserting:  241619
# upserting:  258242
# upserting:  8501
# upserting:  213443
# upserting:  232890
# upserting:  62329080
# upserting:  244552
# upserting:  26311
# upserting:  244477
# upserting:  254211
# upserting:  46156
# upserting:  254280
# upserting:  21306
# upserting:  256886
# upserting:  87377
# upserting:  11871
# upserting:  217973
# upserting:  229641
# upserting:  238588
# upserting:  109777
# upserting:  237318
# upserting:  239432
# upserting:  23309
# upserting:  73963
# upserting:  258029
# upserting:  16081
# upserting:  166292
# upserting:  234677
# upserting:  257951
# upserting:  245489
# upserting:  16421
# upserting:  234516
# upserting:  64557
# upserting:  20800
# upserting:  10004
# upserting:  256206
# upserting:  256209
# upserting:  20793
# upserting:  222609
# upserting:  236333
# upserting:  62620171
# upserting:  237758
# upserting:  232321
# upserting:  235539
# upserting:  10261
# upserting:  54611
# upserting:  143850
# upserting:  247239
# upserting:  18824
# upserting:  11192
# upserting:  232616
# upserting:  24318
# upserting:  68986
# upserting:  20372
# upserting:  37618
# upserting:  67049
# upserting:  8227
# upserting:  229629
# upserting:  239755
# upserting:  64563007
# upserting:  15509
# upserting:  214759
# upserting:  178975
# upserting:  14581
# upserting:  238097
# upserting:  216053
# upserting:  63551413
# upserting:  233270
# upserting:  233276
# upserting:  8465
# upserting:  229691
# upserting:  40533
# upserting:  15348
# upserting:  34512
# upserting:  23173
# upserting:  31066
# upserting:  241639
# upserting:  24685
# upserting:  32417
# upserting:  213114
# upserting:  235059
# upserting:  149975
# upserting:  64480295
# upserting:  244371
# upserting:  173060
# upserting:  257610
# upserting:  82487
# upserting:  214581
# upserting:  64456822
# upserting:  151915
# upserting:  218031
# upserting:  16635
# upserting:  150426
# upserting:  220611
# upserting:  7937
# upserting:  223363
# upserting:  7289
# upserting:  16982
# upserting:  238274
# upserting:  246445
# upserting:  7202
# upserting:  64545824
# upserting:  220048
# upserting:  87365
# upserting:  109485
# upserting:  143818
# upserting:  136264
# upserting:  233345
# upserting:  174319
# upserting:  61562
# upserting:  25309
# upserting:  16539
# upserting:  64636227
# upserting:  64079083
# upserting:  228796
# upserting:  11406
# upserting:  23602
# upserting:  140979
# upserting:  17083
# upserting:  13378
# upserting:  256722
# upserting:  43640
# upserting:  241322
# upserting:  233571
# upserting:  256637
# upserting:  62723
# upserting:  218342
# upserting:  83792
# upserting:  21654
# upserting:  8804
# upserting:  14922
# upserting:  257682
# upserting:  21465
# upserting:  229568
# upserting:  30845
# upserting:  76121
# upserting:  31796
# upserting:  11082
# upserting:  149429
# upserting:  242351
# upserting:  9438
# upserting:  66826
# upserting:  244744
# upserting:  234638
# upserting:  24512
# upserting:  228413
# upserting:  228140
# upserting:  159260
# upserting:  13802
# upserting:  245174
# upserting:  32217
# upserting:  88771
# upserting:  64534933
# upserting:  64531376
# upserting:  51711
# upserting:  241875
# upserting:  256963
# upserting:  213558
# upserting:  76869
# upserting:  255867
# upserting:  64511627
# upserting:  25263
# upserting:  124370
# upserting:  220161
# upserting:  16277
# upserting:  17677
# upserting:  53546
# upserting:  64561354
# upserting:  217053
# upserting:  9368
# upserting:  240456
# upserting:  36867
# upserting:  235948
# upserting:  222636
# upserting:  186378
# upserting:  244643
# upserting:  21270
# upserting:  64536197
# upserting:  14118
# upserting:  237491
# upserting:  246885
# upserting:  26183
# upserting:  9300
# upserting:  84389
# upserting:  22859
# upserting:  236709
# upserting:  53086
# upserting:  20980
# upserting:  168244
# upserting:  246762
# upserting:  14606
# upserting:  217935
# upserting:  14601
# upserting:  233007
# upserting:  57014
# upserting:  255588
# upserting:  232067
# upserting:  237545
# upserting:  247161
# upserting:  11096
# upserting:  242187
# upserting:  24501
# upserting:  62295596
# upserting:  239094
# upserting:  255909
# upserting:  64538461
# upserting:  26589
# upserting:  24724
# upserting:  98129
# upserting:  62349249
# upserting:  104291
# upserting:  60482
# upserting:  48464
# upserting:  221987
# upserting:  215135
# upserting:  64309000
# upserting:  244657
# upserting:  229266
# upserting:  231381
# upserting:  64482559
# upserting:  139039
# upserting:  257470
# upserting:  257474
# upserting:  7845
# upserting:  18913
# upserting:  20240
# upserting:  59599
# upserting:  236060
# upserting:  233522
# upserting:  64530048
# upserting:  26921
# upserting:  229898

# %%
parser1.get_recipes_coll_info()
# Out:
# number of documents: 11111
# number of docs with pages: 9023
# number of docs with nutrition_info 11111
# number of docs with directions 10831
# number of docs with rating_list 10831
# number of docs with nutrition_elements 9757
# number of docs with itemized nutrition 9757
# number of docs with ingredients_list 10831

# %%
parser1.insert_all_nutrition_info()
# Out:
# 9757 out of 11111 recipe documents have itemized nutrition info

# %%
recipes_coll.find_one()['nutrition_info']
# Out:
# [u'Calories:207 kcal',
#  u'',
#  u'',
#  u'',
#  u'10%Fat: 12 g',
#  u'',
#  u'',
#  u'',
#  u'18%Carbs: 23.7g',
#  u'',
#  u'',
#  u'',
#  u'8%Protein: 3.6 g',
#  u'',
#  u'',
#  u'',
#  u'7%Cholesterol: 24 mg',
#  u'',
#  u'',
#  u'',
#  u'8%Sodium: 178 mg',
#  u'',
#  u'',
#  u'',
#  u'7%',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u' **  :    % ',
#  u'',
#  u'*',
#  u'Percent Daily Values are based on a 2,000 calorie diet. Your daily values may be higher or lower depending on your calorie needs.',
#  u'',
#  u'**',
#  u'Nutrient information is not available for all ingredients. Amount is based on available nutrient data.',
#  u'',
#  u'(-)',
#  u'Information is not currently available for this nutrient. If you are following a medically restrictive diet, please consult your doctor or registered dietitian before preparing this recipe for personal consumption.',
#  u'']

# %%
recswnutenotzero = {a['recipe_ID'] for a in recipes_coll.find({"$and":[{'nutrition_info':{"$exists":True,
                                                                                          '$not': {"$size": 0}}}]})}

# %%
len(recswnute)
# Out:
# 11111

# %%
len(recswnutenotzero)
# Out:
# 11111

# %%
rwoc = {a['recipe_ID'] for a in recipes_coll.find({"$and":[{"nutrition_info":{"$exists":True, "$not":{"$size":0}}},
                           {"Cholesterol":{"$exists":False}}]})}

# %%
len(rwoc)
# Out:
# 1354

# %%
recipes_coll.find_one({"$and":[{"nutrition_info":{"$exists":True}},
                           {"Cholesterol":{"$exists":False}}]})['nutrition_info']
# Out:
# [u'']

# %%
list(rwoc)[0]
# Out:
# u'73468'

# %%
recipes_coll.find_one({'recipe_ID':'73468'})
# Out:
# {u'_id': ObjectId('59508130fe023446ff624c3f'),
#  u'description': [u'"This is a really inexpensive way to make lots of yogurt, and it\'s kind of cool to boot!  It also offers and endless amount of possibilities of flavors for those watching sugars. After the first batch, you can use a tablespoon of your own homemade yogurt instead of store-bought."'],
#  u'directions_list': [u'Pour 2 cups of water into a sealable 1 quart container, and stir in the yogurt until dissolved. Whisk in powdered milk until completely blended. Fill with remaining water, and stir. Close the lid, and set in a warm place for 12 to 15 hours. I use a gas oven (turned off), or even a heating pad. Refrigerate, until chilled before serving.',
#   u''],
#  u'ingredients_list': [u'4 cups water, divided',
#   u'1 1/2 tablespoons plain yogurt with active cultures',
#   u'1 3/4 cups dry milk powder'],
#  u'name': [u'Homemade Yogurt'],
#  u'nutrition_elements': [u'::nutrition.fat',
#   u'::nutrition.saturatedFat',
#   u'::nutrition.cholesterol',
#   u'::nutrition.sodium',
#   u'::nutrition.carbohydrates',
#   u'::nutrition.sugars',
#   u'::nutrition.fiber',
#   u'::nutrition.protein',
#   u'::nutrition.vitaminA',
#   u'::nutrition.vitaminC',
#   u'::nutrition.calcium',
#   u'::nutrition.iron',
#   u'::nutrition.potassium',
#   u'::nutrition.thiamin',
#   u'::nutrition.niacin',
#   u'::nutrition.vitaminB6',
#   u'::nutrition.magnesium'],
#  u'nutrition_info': [u'Calories:281 kcal',
#   u'',
#   u'',
#   u'',
#   u'14%Fat: 15 g',
#   u'',
#   u'',
#   u'',
#   u'23%Carbs: 21.9g',
#   u'',
#   u'',
#   u'',
#   u'7%Protein: 15 g',
#   u'',
#   u'',
#   u'',
#   u'30%Cholesterol: 55 mg',
#   u'',
#   u'',
#   u'',
#   u'18%Sodium: 212 mg',
#   u'',
#   u'',
#   u'',
#   u'8%',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u' **  :    % ',
#   u'',
#   u'*',
#   u'Percent Daily Values are based on a 2,000 calorie diet. Your daily values may be higher or lower depending on your calorie needs.',
#   u'',
#   u'**',
#   u'Nutrient information is not available for all ingredients. Amount is based on available nutrient data.',
#   u'',
#   u'(-)',
#   u'Information is not currently available for this nutrient. If you are following a medically restrictive diet, please consult your doctor or registered dietitian before preparing this recipe for personal consumption.',
#   u''],
#  u'nutrition_serving_info': [[u'1 Serving ',
#    u'                    Servings Per Recipe: 4',
#    u'Amount Per Serving',
#    u' **  :    % ',
#    u' **  :    %']],
#  u'rating_list': [u'4.22222232818604', u'5', u'4.22', u'41'],
#  u'recipe_ID': u'73468',
#  u'recipe_times': [u'PT2M', u'PT12H2M'],
#  u'servings': [u'4 servings'],
#  u'servings_config': [u'Added to shopping list.\nGo to shopping list.\n\nIngredients\n\n\n12 h 2 m\n\n\n\n\n4 servings\n\n\n\n281  cals\n\n\n\n\nfor serving adjustment\nServing size has been adjusted!\nOriginal recipe yields 4 servings\n\n\n\nAdjust\n\n\n\n\n\nUS\n\n\n\n\n\nMetric\n\n\nNote:  Recipe directions are for original size.\n\n\n\nNutrition\nAmount per serving (4 total)\n\nCalories:\n281 kcal\n\n\n\n\n\n14%\n\n\nFat: \n15 g\n\n\n\n\n\n23%\n\n\nCarbs: \n21.9g\n\n\n\n\n\n7%\n\n\nProtein: \n15 g\n\n\n\n\n\n30%\n\n\nCholesterol: \n55 mg\n\n\n\n\n\n18%\n\n\nSodium: \n212 mg\n\n\n\n\n\n8%\n\nBased on a 2,000 calorie diet\nSee full nutrition\n\n\n\n\nNutritional Information\nHomemade Yogurt\n\n                    1 Serving \n                    Servings Per Recipe: 4\nAmount Per Serving\n **  :    % \n **  :    % \n\n\n% Daily Value *\n\n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n **  :    % \n\n\n\n\n*\nPercent Daily Values are based on a 2,000 calorie diet. Your daily values may be higher or lower depending on your calorie needs.\n\n\n**\nNutrient information is not available for all ingredients. Amount is based on available nutrient data.\n\n\n(-)\nInformation is not currently available for this nutrient. If you are following a medically restrictive diet, please consult your doctor or registered dietitian before preparing this recipe for personal consumption.\n\n\n\nHide full nutrition\n\n\n\n\n\n\n\n\n\n\nOn SaleWhat\'s on sale near you.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    <![CDATA[\n        <div class="retailer carousel-item">\n            <div class="logo">\n                <img src="<%= this.imageUrl %>"/>\n            </div>\n            <ul class="info">\n                <li><%= this.name %></li>\n                <li><%= this.address %></li>\n                <li><%= this.city %>, <%= this.state %> <%= this.zip %></li>\n                <li class="advertisement"><%= this.sponsoredFlag == true ? "Sponsored" : "" %> </li>\n            </ul>\n        </div>\n    ]]>\n\n\n\n\n Find Me\nor\n\n\nOK\n\nSort stores by\nClosest to me\nMost deals\n\n\n\n\n\n\nHmm. It looks like these ingredients aren\'t on sale today.\n\n\n\n\n\n\n\n\nThese nearby stores have ingredients on sale!\n\n\n\n\n\n\nFind the closest stores\n(uses your location)\n\n\n\n\n\n\n\n\n\n\n\n\n\n4 cups water, divided\n\n\n\n\n\n\n1 1/2 tablespoons plain yogurt with active cultures\n\n\n\n\n\n\n\n\n1 3/4 cups dry milk powder\n\n\n\n\n\n\nAdd all ingredients to list\n\n\n\n\n\n\n\nMay we suggest\n\n\n\n\nADVERTISEMENT']}

# %%
recipes_coll.find({"$and":[{"nutrition_info":{"$exists":True, "$not":{"$size":0}}},
                           {"Cholesterol":{"$exists":False}}]})

# %%
nute_info = recipes_coll.find_one({'recipe_ID':list(rwoc)[11]})['nutrition_info']
