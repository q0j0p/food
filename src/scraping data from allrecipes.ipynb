# %%
from main import Scraper
from main import Parser

# %%
s = Scraper()
# Out:
# Connected to mongodb://localhost:27017/

# %%
p = Parser()
# Out:
# Connected to Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'allrecipes')

# %%
ids = ["17404170"]

# %%
for member_id in ids: 
    c = s.get_member_pages(member_id)
    p.get_member_parsed_data(memberID=member_id)
# Out:
# accessing http://allrecipes.com/cook/17404170/about-me/
# accessing http://allrecipes.com/cook/17404170/favorites/
# accessing http://allrecipes.com/cook/17404170/following/
# accessing http://allrecipes.com/cook/17404170/followers/
# accessing http://allrecipes.com/cook/17404170/reviews/
# accessing http://allrecipes.com/cook/17404170/made-it/
# accessing http://allrecipes.com/cook/17404170/recipes/
# scraping complete
# Number of documents for 17404170: 1
#
#              member_ID is 17404170
#              has "about me" page: False
#              number of followers: None
#              number of followed: 1
#              number of reviews: None
#              number of favorites: 20
#              number of recipes made: None
#              number of personal recipes: 1

# %% [markdown]
# ===
#
# Still works-- what needs to be done now?
#
# * Enable extraction of data while scraping
# * Set up auto scraping
#
# ===

# %%
p.get_members_coll_info()
# Out:
# number of member_pages: 1453
# number of docs with member_IDs: 1452
# number of docs with followers_dict 1452
# number of docs with following_dict 1452
# number of docs with reviews_dict 1452
# number of docs with favorites_dict 1452
# number of docs with madeits_dict 1452
# number of docs with aboutme 1452
# number of docs with personal 20
# number of docs with nutrition values 1430

# %%
p.get_recipes_coll_info()
# Out:
# number of documents: 11114
# number of docs with pages: 9026
# number of docs with nutrition_info 11114
# number of docs with directions 10834
# number of docs with rating_list 10834
# number of docs with nutrition_elements 9760
# number of docs with itemized nutrition 9757
# number of docs with ingredients_list 10834

# %%
p.get_recipe_data_from_recipe_pages_coll()
# Out:
# Number of docs in recipe_pages_coll 2088
# Number of docs in recipe_pages with ingredients info: 10831
# Number of documents to populate: 133
# upserting:  62899796
# upserting:  62448402
# upserting:  64597362
# upserting:  62163092
# upserting:  64545824
# upserting:  64562440
# upserting:  64642548
# upserting:  63894739
# upserting:  64561354
# upserting:  64642523
# upserting:  64644973
# upserting:  64530219
# upserting:  62623777
# upserting:  63692021
# upserting:  64427708
# upserting:  63551390
# upserting:  64401276
# upserting:  64534212
# upserting:  64527381
# upserting:  64582392
# upserting:  64569888
# upserting:  64132394
# upserting:  63603073
# upserting:  64563007
# upserting:  64499898
# upserting:  64624620
# upserting:  63668876
# upserting:  64504099
# upserting:  63551413
# upserting:  64220706
# upserting:  64555223
# upserting:  64527378
# upserting:  64405996
# upserting:  64536211
# upserting:  64641571
# upserting:  64581466
# upserting:  64569487
# ...

# %%
p.get_recipe_data()
# Out:
# Count of recipe documents with no recipe data: 0
# Count of recipe documents with no recipe data: 0
# Count of member documents with no recipe name field: 0

# %%
s.recipes_coll.find_one().keys()
# Out:
# [u'Cholesterol',
#  u'nutrition',
#  u'Carbs',
#  u'recipe_times',
#  u'nutrition_elements',
#  u'Sodium',
#  u'name',
#  u'nutrition_serving_info',
#  u'description',
#  u'Calories',
#  u'Fat',
#  u'servings_config',
#  u'recipe_ID',
#  u'rating_list',
#  u'servings',
#  u'nutrition_info',
#  u'Protein',
#  u'_id',
#  u'page',
#  u'directions_list',
#  u'ingredients_list']

# %%
s.recipes_coll.find_one()['page']
# Out:
# u'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml"><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}</style>\n    <title>Outrageous Chocolate Chip Cookies Recipe - Allrecipes.com</title>\n        <meta content="Outrageous Chocolate Chip Cookies Recipe" property="og:title" />\n\n    <meta content="Allrecipes" property="og:site_name" />\n    <meta charset="utf-8" />\n    <meta content="width=device-width, initial-scale=1.0" name="viewport" />\n        <meta content="A great combination of chocolate chips, oatmeal, and peanut butter." name="description" id="metaDescription" />\n        <meta content="A great combination of chocolate chips, oatmeal, and peanut butter." property="og:description" />\n                <meta content="noodp,noydir" name="robots" />\n\n    \n\n        <link href="http://allrecipes.com/recipe/10141/ou
# ...

# %%
import os
import webbrowser

html = s.recipes_coll.find_one()['page'].encode('utf-8')
path = os.path.abspath('temp.html')
url = 'file://' + path

with open(path, 'w') as f:
    f.write(html)
webbrowser.open(url)
# Out:
# True

# %%
p.members_coll.find_one({'member_ID':member_id}).keys()
# Out:
# [u'personalrecipe_dict',
#  u'followers_dict',
#  u'reviews_dict',
#  u'following_id_list',
#  u'madeits_recipe_id_list',
#  u'favorites_dict',
#  u'reviews_recipe_id_list',
#  u'following_dict',
#  u'member_ID',
#  u'favorites_recipe_id_list',
#  u'_id',
#  u'aboutme',
#  u'madeits_dict',
#  u'followers_id_list']

# %%
s.get_recipe_page("9023")

# %%
p.get_recipe_data()
# Out:
# Count of recipe documents with no recipe data: 1
# Count of recipe documents with no recipe data: 0
# 9023
# Count of member documents with no recipe name field: 0

# %%
p.recipe_pages_coll.count()
# Out:
# 2088

# %%
p.recipes_coll.count()
# Out:
# 11114

# %%
c.find_one()['member_ID']
# Out:
# u'64043'

# %%
c.find_one().keys()
# Out:
# [u'favorites_page',
#  u'following_page',
#  u'reviews_page',
#  u'aboutme_page',
#  u'madeit_page',
#  u'link',
#  u'member_ID',
#  u'followers_page',
#  u'_id',
#  u'recipes_page']

# %%
c.find_one({'member_ID':'1029018'})['link']
# Out:
# u'http://allrecipes.com/cook/1029018'

# %%
p.get_reviews_data(c.find_one({'member_ID':'1029018'})['reviews_page'])
# Out:
# ([u'24445', u'11967', u'16207', u'15715', u'74950'],
#  [{'recipe_ID': u'24445',
#    'recipe_link': u'/recipe/24445/chewy-chocolate-chip-oatmeal-cookies/',
#    'recipe_rating': u'5',
#    'recipe_title': u'Chewy Chocolate Chip Oatmeal Cookies',
#    'review_text': u'Yum. Yum. mine came out flat, lacy and chewy with super flavor. Left out the walnuts because of the kids. Besdies that, followed the recipe perfectly.  Everyone *loves* them...will definitely make again. Thanks for sharing!'},
#   {'recipe_ID': u'11967',
#    'recipe_link': u'/recipe/11967/angel-chicken-pasta/',
#    'recipe_rating': u'4',
#    'recipe_title': u'Angel Chicken Pasta',
#    'review_text': u'I served this to guests and everyone loved it. They took the recipe home. I knew from the ingredients to expect this dish to be rich. I followed it exactly and it came out perfect. Quick and easy but appeared as though I spent lots of time preparing. Thanks for sharing!'},
#   {'recipe_ID': u'16207',
# ...

# %%
p.get_favorites_data(c.find_one({'member_ID':'1029018'})['favorites_page'])
# Out:
# ([], {})

# %%
p.get_following_data(c.find_one({'member_ID':'1029018'})['following_page'])
# Out:
# ([], {})

# %%
p.get_madeits_data(c.find_one({'member_ID':'1029018'})['madeit_page'])
# Out:
# ([u'70522', u'24445', u'11967', u'16207', u'15715', u'74950'],
#  {u' Angel Chicken Pasta ': u'11967',
#   u' Bacon Mushroom Chicken ': u'16207',
#   u' Chewy Chocolate Chip Oatmeal Cookies ': u'24445',
#   u' Garlic Cheddar Chicken ': u'70522',
#   u' Mini Meatloaves ': u'15715',
#   u" My Amish Friend's Caramel Corn ": u'74950'})

# %%
p.get_aboutme_data(c.find_one({'member_ID':'1029018'})['aboutme_page'])
# Out:
# (u'1029018', [u''])

# %%
p.get_favorites_data()

# %%
p.get_personalrecipe_data(c.find_one({'member_ID':'1029018'})['recipes_page'])
# Out:
# ([u'70522'], {u' Garlic Cheddar Chicken ': u'70522'})

# %%
p.get_member_parsed_data(memberID="1029018")
# Out:
# Number of documents for 1029018: 1
#
#              member_ID is 1029018
#              has "about me" page: True
#              number of followers: 14
#              number of followed: None
#              number of reviews: 5
#              number of favorites: None
#              number of recipes made: 6

# %%
# !python q2_sigmoid.py
