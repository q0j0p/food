# %%
# Automatically updates imports 
# %load_ext autoreload
# %autoreload 2

# %%
import time
from urllib import urlencode
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from bs4 import BeautifulSoup as BS
import random
import requests
import pymongo
import pandas as pd
import re
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from IPython.display import Image
import boto3
import cPickle
import os

# %%
dcap = dict(DesiredCapabilities.PHANTOMJS)
dcap["phantomjs.page.settings.userAgent"] = (
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36/"
)

# %%
browser = webdriver.PhantomJS(desired_capabilities=dcap)
browser.implicitly_wait(10)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-7b50784772c2> in <module>()
# ----> 1 browser = webdriver.PhantomJS(desired_capabilities=dcap)
#       2 browser.implicitly_wait(10)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/selenium/webdriver/phantomjs/webdriver.pyc in __init__(self, executable_path, port, desired_capabilities, service_args, service_log_path)
#      50             service_args=service_args,
#      51             log_path=service_log_path)
# ---> 52         self.service.start()
#      53
#      54         try:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/selenium/webdriver/common/service.pyc in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ...

# %%
with open('memlist.txt', 'r') as f: 
        meml = [x for x in f.readlines() ]
memlist = [m.strip() for m in meml]

# %%
memlist = ['5255353']

# %%
aboutme_page = []

# %%
for i, member in enumerate(memlist[550:]):
    browser.get("http://allrecipes.com/cook/"+member + "/about-me/")
    print "list item number {}, {} \n  {}\n\n\n".format(i+550, member,browser.current_url)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight/1.2);")
    time.sleep(5)
    time.sleep(5 + random.random() * 5)
    aboutme_page.append(browser.page_source)
    browser.save_screenshot('aboutme{}.png'.format(member))
# Out:
# list item number 550, 3589345
#   http://allrecipes.com/cook/3589345/about-me/
#
#
#
# list item number 551, 15611466
#   http://allrecipes.com/cook/15611466/about-me/
#
#
#
# list item number 552, 7564453
#   http://allrecipes.com/cook/7564453/about-me/
#
#
#
# list item number 553, 3974230
#   http://allrecipes.com/cook/3974230/about-me/
#
#
#
# list item number 554, 14386388
#   http://allrecipes.com/cook/14386388/about-me/
#
#
#
# list item number 555, 4859904
#   http://allrecipes.com/cook/4859904/about-me/
#
#
#
# list item number 556, 3865323
#   http://allrecipes.com/cook/3865323/about-me/
#
#
#
# list item number 557, 18029322
#   http://allrecipes.com/cook/18029322/following/
#
#
#
# list item number 558, 11515048
#   http://allrecipes.com/cook/11515048/made-it/
#
#
#
# list item number 559, 3348938
#   http://allrecipes.com/cook/3348938/about-me/
#
#
#
# list item number 560, 7761606
#   http://allrecipes.com/cook/7761606/about-me/
#
#
#
# list item number 561, 18055311
# ...

# %%
browser.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-52e7067fd9b4> in <module>()
# ----> 1 browser.close()
#
# NameError: name 'browser' is not defined

# %%
Image('aboutme64043.png')

# %%
len(aboutme_page)
# Out:
# 265

# %%
cPickle.dump(aboutme_page, open('aboutme2_page.p', 'wb'))

# %%
os.environ.keys()

# %%
print os.getenv("AWS_ACCESS_KEY")
# Out:
# AKIAJJACP4LP7QO3A52A

# %%
print os.environ.get('$AWS_ACCESS_KEY')
# Out:
# None

# %%
AWS_KEY = os.environ['AWS_ACCESS_KEY']
AWS_SECRET = os.environ['AWS_SECRET_ACCESS_KEY']

# %%
s3 = boto3.resource('s3')

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# aws-logs-848585299073-us-east-1
# firstbucketforaws
# ohailolcat
# ppca111

# %%
aws_connection = boto3.S3Connection(AWS_KEY, AWS_SECRET)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-08d2669b8bcc> in <module>()
# ----> 1 aws_connection = boto3.S3Connection(AWS_KEY, AWS_SECRET)
#
# AttributeError: 'module' object has no attribute 'S3Connection'

# %%
ls

# %%
# Upload a new file
data = open('aboutme2_page.p', 'rb')
s3.Bucket('ohailolcat').put_object(Key='aboutme2_page.p ', Body=data)
# Out:
# s3.Object(bucket_name='ohailolcat', key='aboutme2_page.p ')

# %%
s3.Bucket('ohailolcat').
# Out:
# s3.Bucket(name='ohailolcat')
